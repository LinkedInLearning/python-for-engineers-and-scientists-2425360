# %% [markdown]
# # 04_06_snakemake.ipynb - Scientific workflows with Snakemake

# %%
# conda install -c bioconda -c conda-forge snakemake-minimal

# %%
# %%file Snakefile
#
# events = ['GW170817-v3', 'GW190521_074359-v1', 'GW190814-v2', 'GW190412-v3',
#           'GW190828_063405-v1', 'GW170814-v3', 'GW170608-v3', 'GW190408_181802-v1',
#           'GW190521-v3']
#
# rule stack:
#     input:
#         expand("events/{id}.png", id=events)
#     output:
#         "events/allevents.png"
#     run:
#         from PIL import Image
#         import numpy as np
#
#         # load all images to numpy arrays
#         images = [np.array(Image.open(imagefile)) for imagefile in input]
#         # stack the arrays vertically
#         stacked = np.vstack(images)
#         # convert stacked array to PIL image, then save
#         Image.fromarray(stacked).save(output[0])
#
# rule plot:
#     input:
#         "events/{id}.json"
#     output:
#         "events/{id}.png"
#     shell:
#         "python plotsignal.py {wildcards.id} -C events"
#
# rule download:
#     output:
#         "events/{id}.json"
#     shell:
#         "python hdfdownload.py {wildcards.id} -C events"
# Out:
# Overwriting Snakefile

# %%
# !snakemake -j 1 events/GW150914-v3.json
# Out:
# Building DAG of jobs...
# Using shell: /bin/bash
# Provided cores: 1 (use --cores to define parallelism)
# Rules claiming more threads will be scaled down.
# Job counts:
# 	count	jobs
# 	1	download
# 	1
#
# [Mon Jul 26 16:29:38 2021]
# rule download:
#     output: events/GW150914-v3.json
#     jobid: 0
#     wildcards: id=GW150914-v3
#
# Downloading https://www.gw-openscience.org/eventapi/json/allevents to events/catalog.json.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3 to events/GW150914-v3.json.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126259447-32.hdf5 to events/H1-GW150914-v3.hdf5.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126259447-32.hdf5 to events/L1-GW150914-v3.hdf5.
# [Mon Jul 26 16:29:50 2021]
# Finished job 0.
# 1 of 1 steps (100%) done
# Complete log: /Users/mvallisneri/Desktop/Exercise Files/Ch04/.snakemake/log/2021-07-26T162938.046424.snakemake.log

# %%
# !snakemake -j 1 events/GW170817-v3.png
# Out:
# Building DAG of jobs...
# Using shell: /bin/bash
# Provided cores: 1 (use --cores to define parallelism)
# Rules claiming more threads will be scaled down.
# Job counts:
# 	count	jobs
# 	1	download
# 	1	plot
# 	2
#
# [Mon Jul 26 16:30:24 2021]
# rule download:
#     output: events/GW170817-v3.json
#     jobid: 1
#     wildcards: id=GW170817-v3
#
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170817/v3 to events/GW170817-v3.json.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170817/v3/H-H1_GWOSC_4KHZ_R1-1187008867-32.hdf5 to events/H1-GW170817-v3.hdf5.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170817/v3/L-L1_GWOSC_4KHZ_R1-1187008867-32.hdf5 to events/L1-GW170817-v3.hdf5.
# [Mon Jul 26 16:30:36 2021]
# Finished job 1.
# 1 of 2 steps (50%) done
#
# [Mon Jul 26 16:30:36 2021]
# rule plot:
#     input: events/GW170817-v3.json
#     output: events/GW170817-v3.png
#     jobid: 0
#     wildcards: id=GW170817-v3
#
# [Mon Jul 26 16:30:38 2021]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: /Users/mvallisneri/Desktop/Exercise Files/Ch04/.snakemake/log/2021-07-26T163024.194629.snakemake.log

# %%
# !snakemake -n
# Out:
# Building DAG of jobs...
# Job counts:
# 	count	jobs
# 	8	download
# 	8	plot
# 	1	stack
# 	17
#
# [Mon Jul 26 16:31:58 2021]
# rule download:
#     output: events/GW190408_181802-v1.json
#     jobid: 17
#     wildcards: id=GW190408_181802-v1
#
#
# [Mon Jul 26 16:31:58 2021]
# rule download:
#     output: events/GW170814-v3.json
#     jobid: 15
#     wildcards: id=GW170814-v3
#
#
# [Mon Jul 26 16:31:58 2021]
# rule download:
#     output: events/GW190521_074359-v1.json
#     jobid: 11
#     wildcards: id=GW190521_074359-v1
#
#
# [Mon Jul 26 16:31:58 2021]
# rule download:
#     output: events/GW170608-v3.json
#     jobid: 16
#     wildcards: id=GW170608-v3
#
#
# [Mon Jul 26 16:31:58 2021]
# rule download:
#     output: events/GW190828_063405-v1.json
#     jobid: 14
#     wildcards: id=GW190828_063405-v1
#
#
# [Mon Jul 26 16:31:58 2021]
# rule download:
#     output: events/GW190521-v3.json
#     jobid: 18
#     wildcards: id=GW190521-v3
#
#
# [Mon Jul 26 16:31:58 2021]
# rule download:
#     output: events/GW190814-v2.json
#     jobid: 12
#     wildcards: id=GW190814-v2
#
#
# [Mon Jul 26 16:31:58 2021]
# rule download:
#     output: events/GW190412-v3.json
#     jobid: 13
#     wildcards: id=GW190412-v3
#
#
# [Mon Jul 26 16:31:58 2021]
# rule plot:
#     input: events/GW190408_181802-v1.json
#     output: events/GW190408_181802-v1.png
#     jobid: 8
#     wildcards: id=GW190408_181802-v1
#
#
# [Mon Jul 26 16:31:58 2021]
# rule plot:
#     input: events/GW190412-v3.json
#     output: events/GW190412-v3.png
#     jobid: 4
#     wildcards: id=GW190412-v3
#
#
# [Mon Jul 26 16:31:58 2021]
# rule plot:
#     input: events/GW190814-v2.json
#     output: events/GW190814-v2.png
#     jobid: 3
#     wildcards: id=GW190814-v2
#
#
# [Mon Jul 26 16:31:58 2021]
# rule plot:
#     input: events/GW190521-v3.json
#     output: events/GW190521-v3.png
#     jobid: 9
#     wildcards: id=GW190521-v3
#
#
# [Mon Jul 26 16:31:58 2021]
# rule plot:
#     input: events/GW170814-v3.json
#     output: events/GW170814-v3.png
#     jobid: 6
#     wildcards: id=GW170814-v3
#
#
# [Mon Jul 26 16:31:58 2021]
# rule plot:
#     input: events/GW190521_074359-v1.json
#     output: events/GW190521_074359-v1.png
#     jobid: 2
#     wildcards: id=GW190521_074359-v1
#
#
# [Mon Jul 26 16:31:58 2021]
# rule plot:
#     input: events/GW170608-v3.json
#     output: events/GW170608-v3.png
#     jobid: 7
#     wildcards: id=GW170608-v3
#
#
# [Mon Jul 26 16:31:58 2021]
# rule plot:
#     input: events/GW190828_063405-v1.json
#     output: events/GW190828_063405-v1.png
#     jobid: 5
#     wildcards: id=GW190828_063405-v1
#
#
# [Mon Jul 26 16:31:58 2021]
# rule stack:
#     input: events/GW170817-v3.png, events/GW190521_074359-v1.png, events/GW190814-v2.png, events/GW190412-v3.png, events/GW190828_063405-v1.png, events/GW170814-v3.png, events/GW170608-v3.png, events/GW190408_181802-v1.png, events/GW190521-v3.png
#     output: events/allevents.png
#     jobid: 0
#
# Job counts:
# 	count	jobs
# 	8	download
# 	8	plot
# 	1	stack
# 	17
# This was a dry-run (flag -n). The order of jobs does not reflect the order of execution.

# %%
# !snakemake -j 4
# Out:
# Building DAG of jobs...
# Using shell: /bin/bash
# Provided cores: 4
# Rules claiming more threads will be scaled down.
# Job counts:
# 	count	jobs
# 	8	download
# 	8	plot
# 	1	stack
# 	17
#
# [Mon Jul 26 16:32:21 2021]
# rule download:
#     output: events/GW190521_074359-v1.json
#     jobid: 11
#     wildcards: id=GW190521_074359-v1
#
#
# [Mon Jul 26 16:32:21 2021]
# rule download:
#     output: events/GW190408_181802-v1.json
#     jobid: 17
#     wildcards: id=GW190408_181802-v1
#
#
# [Mon Jul 26 16:32:21 2021]
# rule download:
#     output: events/GW170814-v3.json
#     jobid: 15
#     wildcards: id=GW170814-v3
#
#
# [Mon Jul 26 16:32:21 2021]
# rule download:
#     output: events/GW190412-v3.json
#     jobid: 13
#     wildcards: id=GW190412-v3
#
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-2/GW190521_074359/v1 to events/GW190521_074359-v1.json.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-2/GW190408_181802/v1 to events/GW190408_181802-v1.json.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170814/v3 to events/GW170814-v3.json.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-2/GW190412/v3 to events/GW190412-v3.json.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170814/v3/H-H1_GWOSC_4KHZ_R1-1186741846-32.hdf5 to events/H1-GW170814-v3.hdf5.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-2/GW190408_181802/v1/H-H1_GWOSC_4KHZ_R1-1238782685-32.hdf5 to events/H1-GW190408_181802-v1.hdf5.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-2/GW190521_074359/v1/H-H1_GWOSC_4KHZ_R1-1242459842-32.hdf5 to events/H1-GW190521_074359-v1.hdf5.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-2/GW190412/v3/H-H1_GWOSC_4KHZ_R1-1239082247-32.hdf5 to events/H1-GW190412-v3.hdf5.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170814/v3/L-L1_GWOSC_4KHZ_R1-1186741846-32.hdf5 to events/L1-GW170814-v3.hdf5.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-2/GW190408_181802/v1/L-L1_GWOSC_4KHZ_R1-1238782685-32.hdf5 to events/L1-GW190408_181802-v1.hdf5.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-2/GW190521_074359/v1/L-L1_GWOSC_4KHZ_R1-1242459842-32.hdf5 to events/L1-GW190521_074359-v1.hdf5.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-2/GW190412/v3/L-L1_GWOSC_4KHZ_R1-1239082247-32.hdf5 to events/L1-GW190412-v3.hdf5.
# [Mon Jul 26 16:32:26 2021]
# Finished job 15.
# 1 of 17 steps (6%) done
#
# [Mon Jul 26 16:32:26 2021]
# rule plot:
#     input: events/GW170814-v3.json
#     output: events/GW170814-v3.png
#     jobid: 6
#     wildcards: id=GW170814-v3
#
# [Mon Jul 26 16:32:26 2021]
# Finished job 17.
# 2 of 17 steps (12%) done
#
# [Mon Jul 26 16:32:26 2021]
# rule plot:
#     input: events/GW190408_181802-v1.json
#     output: events/GW190408_181802-v1.png
#     jobid: 8
#     wildcards: id=GW190408_181802-v1
#
# [Mon Jul 26 16:32:26 2021]
# Finished job 11.
# 3 of 17 steps (18%) done
#
# [Mon Jul 26 16:32:26 2021]
# rule plot:
#     input: events/GW190521_074359-v1.json
#     output: events/GW190521_074359-v1.png
#     jobid: 2
#     wildcards: id=GW190521_074359-v1
#
# [Mon Jul 26 16:32:26 2021]
# Finished job 13.
# 4 of 17 steps (24%) done
#
# [Mon Jul 26 16:32:26 2021]
# rule plot:
#     input: events/GW190412-v3.json
#     output: events/GW190412-v3.png
#     jobid: 4
#     wildcards: id=GW190412-v3
#
# [Mon Jul 26 16:32:28 2021]
# Finished job 6.
# 5 of 17 steps (29%) done
#
# [Mon Jul 26 16:32:28 2021]
# rule download:
#     output: events/GW190521-v3.json
#     jobid: 18
#     wildcards: id=GW190521-v3
#
# [Mon Jul 26 16:32:28 2021]
# Finished job 8.
# 6 of 17 steps (35%) done
#
# [Mon Jul 26 16:32:28 2021]
# rule download:
#     output: events/GW190828_063405-v1.json
#     jobid: 14
#     wildcards: id=GW190828_063405-v1
#
# [Mon Jul 26 16:32:28 2021]
# Finished job 2.
# 7 of 17 steps (41%) done
#
# [Mon Jul 26 16:32:28 2021]
# rule download:
#     output: events/GW190814-v2.json
#     jobid: 12
#     wildcards: id=GW190814-v2
#
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-2/GW190521/v3 to events/GW190521-v3.json.
# [Mon Jul 26 16:32:28 2021]
# Finished job 4.
# 8 of 17 steps (47%) done
#
# [Mon Jul 26 16:32:28 2021]
# rule download:
#     output: events/GW170608-v3.json
#     jobid: 16
#     wildcards: id=GW170608-v3
#
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-2/GW190828_063405/v1 to events/GW190828_063405-v1.json.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-2/GW190814/v2 to events/GW190814-v2.json.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170608/v3 to events/GW170608-v3.json.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-2/GW190521/v3/H-H1_GWOSC_4KHZ_R1-1242442952-32.hdf5 to events/H1-GW190521-v3.hdf5.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170608/v3/H-H1_GWOSC_4KHZ_R1-1180922479-32.hdf5 to events/H1-GW170608-v3.hdf5.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-2/GW190814/v2/H-H1_GWOSC_4KHZ_R1-1249852241-32.hdf5 to events/H1-GW190814-v2.hdf5.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-2/GW190828_063405/v1/H-H1_GWOSC_4KHZ_R1-1251009248-32.hdf5 to events/H1-GW190828_063405-v1.hdf5.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170608/v3/L-L1_GWOSC_4KHZ_R1-1180922479-32.hdf5 to events/L1-GW170608-v3.hdf5.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-2/GW190814/v2/L-L1_GWOSC_4KHZ_R1-1249852241-32.hdf5 to events/L1-GW190814-v2.hdf5.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-2/GW190828_063405/v1/L-L1_GWOSC_4KHZ_R1-1251009248-32.hdf5 to events/L1-GW190828_063405-v1.hdf5.
# Downloading https://www.gw-openscience.org/eventapi/json/GWTC-2/GW190521/v3/L-L1_GWOSC_4KHZ_R1-1242442952-32.hdf5 to events/L1-GW190521-v3.hdf5.
# [Mon Jul 26 16:32:33 2021]
# Finished job 16.
# 9 of 17 steps (53%) done
#
# [Mon Jul 26 16:32:33 2021]
# rule plot:
#     input: events/GW170608-v3.json
#     output: events/GW170608-v3.png
#     jobid: 7
#     wildcards: id=GW170608-v3
#
# [Mon Jul 26 16:32:33 2021]
# Finished job 12.
# 10 of 17 steps (59%) done
#
# [Mon Jul 26 16:32:33 2021]
# rule plot:
#     input: events/GW190814-v2.json
#     output: events/GW190814-v2.png
#     jobid: 3
#     wildcards: id=GW190814-v2
#
# [Mon Jul 26 16:32:33 2021]
# Finished job 14.
# 11 of 17 steps (65%) done
#
# [Mon Jul 26 16:32:33 2021]
# rule plot:
#     input: events/GW190828_063405-v1.json
#     output: events/GW190828_063405-v1.png
#     jobid: 5
#     wildcards: id=GW190828_063405-v1
#
# [Mon Jul 26 16:32:33 2021]
# Finished job 18.
# 12 of 17 steps (71%) done
#
# [Mon Jul 26 16:32:33 2021]
# rule plot:
#     input: events/GW190521-v3.json
#     output: events/GW190521-v3.png
#     jobid: 9
#     wildcards: id=GW190521-v3
#
# [Mon Jul 26 16:32:35 2021]
# Finished job 5.
# 13 of 17 steps (76%) done
# [Mon Jul 26 16:32:35 2021]
# Finished job 3.
# 14 of 17 steps (82%) done
# [Mon Jul 26 16:32:35 2021]
# Finished job 7.
# 15 of 17 steps (88%) done
# [Mon Jul 26 16:32:35 2021]
# Finished job 9.
# 16 of 17 steps (94%) done
#
# [Mon Jul 26 16:32:35 2021]
# rule stack:
#     input: events/GW170817-v3.png, events/GW190521_074359-v1.png, events/GW190814-v2.png, events/GW190412-v3.png, events/GW190828_063405-v1.png, events/GW170814-v3.png, events/GW170608-v3.png, events/GW190408_181802-v1.png, events/GW190521-v3.png
#     output: events/allevents.png
#     jobid: 0
# Job counts:
# 	count	jobs
# 	1	stack
# 	1
# [Mon Jul 26 16:32:36 2021]
# Finished job 0.
# 17 of 17 steps (100%) done
# Complete log: /Users/mvallisneri/Desktop/Exercise Files/Ch04/.snakemake/log/2021-07-26T163221.348634.snakemake.log

# %%
# on Windows !start events/allevents.png
# !open events/allevents.png
