# %% [markdown]
# # 04_02_web.ipynb - Web resources with requests and JSON

# %%
import json
import os

import requests

# %%
r = requests.get('https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3')

# %%
r
# Out:
# <Response [200]>

# %%
# if requests.get fails for network problems
# you can use the cached version in the exercise files:
# import pickle
# r = pickle.load(open('cache/GW150914-v3.pickle', 'rb'))

# %%
r.ok
# Out:
# True

# %%
r.content
# Out:
# b'{\n  "events": {\n    "GW150914-v3": {\n      "GPS": 1126259462.4,\n      "catalog.shortName": "GWTC-1-confident",\n      "chi_eff": -0.01,\n      "chi_eff_lower": -0.13,\n      "chi_eff_unit": "",\n      "chi_eff_upper": 0.12,\n      "chirp_mass": null,\n      "chirp_mass_lower": null,\n      "chirp_mass_source": 28.6,\n      "chirp_mass_source_lower": -1.5,\n      "chirp_mass_source_unit": "M_sun",\n      "chirp_mass_source_upper": 1.7,\n      "chirp_mass_unit": null,\n      "chirp_mass_upper": null,\n      "commonName": "GW150914",\n      "far": 1e-07,\n      "far_lower": null,\n      "far_unit": "yr^-1",\n      "far_upper": null,\n      "final_mass_source": 63.1,\n      "final_mass_source_lower": -3.0,\n      "final_mass_source_unit": "M_sun",\n      "final_mass_source_upper": 3.4,\n      "jsonurl": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3",\n      "luminosity_distance": 440.0,\n      "luminosity_distance_lower": -170.0,\n      "luminosity_distance_unit": "Mpc",\n      "luminosity_distance_upper": 150.0,\n      "mass_1_source": 35.6,\n      "mass_1_source_lower": -3.1,\n      "mass_1_source_unit": "M_sun",\n      "mass_1_source_upper": 4.7,\n      "mass_2_source": 30.6,\n      "mass_2_source_lower": -4.4,\n      "mass_2_source_unit": "M_sun",\n      "mass_2_source_upper": 3.0,\n      "network_matched_filter_snr": 24.4,\n      "network_matched_filter_snr_lower": null,\n      "network_matched_filter_snr_unit": "",\n      "network_matched_filter_snr_upper": null,\n      "parameters": {\n        "gwtc1_cwb_GW150914": {\n          "data_url": "",\n          "far": 0.000163,\n          "far_lower": null,\n          "far_unit": "yr^-1",\n          "far_upper": null,\n          "network_matched_filter_snr": 25.2,\n          "network_matched_filter_snr_lower": null,\n          "network_matched_filter_snr_unit": "",\n          "network_matched_filter_snr_upper": null\n        },\n        "gwtc1_gstlal_GW150914": {\n          "data_url": "",\n          "far": 1e-07,\n          "far_lower": null,\n          "far_unit": "yr^-1",\n          "far_upper": null,\n          "network_matched_filter_snr": 24.4,\n          "network_matched_filter_snr_lower": null,\n          "network_matched_filter_snr_unit": "",\n          "network_matched_filter_snr_upper": null\n        },\n        "gwtc1_pe_GW150914": {\n          "E_rad": 3.1,\n          "E_rad_lower": -0.4,\n          "E_rad_unit": "M_sun c^2",\n          "E_rad_upper": 0.4,\n          "L_peak": 3.6,\n          "L_peak_lower": -0.4,\n          "L_peak_unit": "10^56 erg s^-1",\n          "L_peak_upper": 0.4,\n          "a_final": 0.69,\n          "a_final_lower": -0.04,\n          "a_final_unit": "",\n          "a_final_upper": 0.05,\n          "chi_eff": -0.01,\n          "chi_eff_lower": -0.13,\n          "chi_eff_unit": "",\n          "chi_eff_upper": 0.12,\n          "chirp_mass_source": 28.6,\n          "chirp_mass_source_lower": -1.5,\n          "chirp_mass_source_unit": "M_sun",\n          "chirp_mass_source_upper": 1.7,\n          "data_url": "https://dcc.ligo.org/public/0157/P1800370/005/GW150914_GWTC-1.hdf5",\n          "final_mass_source": 63.1,\n          "final_mass_source_lower": -3.0,\n          "final_mass_source_unit": "M_sun",\n          "final_mass_source_upper": 3.4,\n          "geocent_time": 1126259462.4,\n          "geocent_time_lower": null,\n          "geocent_time_unit": "",\n          "geocent_time_upper": null,\n          "luminosity_distance": 440.0,\n          "luminosity_distance_lower": -170.0,\n          "luminosity_distance_unit": "Mpc",\n          "luminosity_distance_upper": 150.0,\n          "mass_1_source": 35.6,\n          "mass_1_source_lower": -3.1,\n          "mass_1_source_unit": "M_sun",\n          "mass_1_source_upper": 4.7,\n          "mass_2_source": 30.6,\n          "mass_2_source_lower": -4.4,\n          "mass_2_source_unit": "M_sun",\n          "mass_2_source_upper": 3.0,\n          "redshift": 0.09,\n   ...

# %%
print(r.text)
# Out:
# {
#   "events": {
#     "GW150914-v3": {
#       "GPS": 1126259462.4,
#       "catalog.shortName": "GWTC-1-confident",
#       "chi_eff": -0.01,
#       "chi_eff_lower": -0.13,
#       "chi_eff_unit": "",
#       "chi_eff_upper": 0.12,
#       "chirp_mass": null,
#       "chirp_mass_lower": null,
#       "chirp_mass_source": 28.6,
#       "chirp_mass_source_lower": -1.5,
#       "chirp_mass_source_unit": "M_sun",
#       "chirp_mass_source_upper": 1.7,
#       "chirp_mass_unit": null,
#       "chirp_mass_upper": null,
#       "commonName": "GW150914",
#       "far": 1e-07,
#       "far_lower": null,
#       "far_unit": "yr^-1",
#       "far_upper": null,
#       "final_mass_source": 63.1,
#       "final_mass_source_lower": -3.0,
#       "final_mass_source_unit": "M_sun",
#       "final_mass_source_upper": 3.4,
#       "jsonurl": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3",
#       "luminosity_distance": 440.0,
#       "luminosity_distance_lower": -170.0,
#       "luminosity_distance_unit": "Mpc",
#       "luminosity_distance_upper": 150.0,
#       "mass_1_source": 35.6,
#       "mass_1_source_lower": -3.1,
#       "mass_1_source_unit": "M_sun",
#       "mass_1_source_upper": 4.7,
#       "mass_2_source": 30.6,
#       "mass_2_source_lower": -4.4,
#       "mass_2_source_unit": "M_sun",
#       "mass_2_source_upper": 3.0,
#       "network_matched_filter_snr": 24.4,
#       "network_matched_filter_snr_lower": null,
#       "network_matched_filter_snr_unit": "",
#       "network_matched_filter_snr_upper": null,
#       "parameters": {
#         "gwtc1_cwb_GW150914": {
#           "data_url": "",
#           "far": 0.000163,
#           "far_lower": null,
#           "far_unit": "yr^-1",
#           "far_upper": null,
#           "network_matched_filter_snr": 25.2,
#           "network_matched_filter_snr_lower": null,
#           "network_matched_filter_snr_unit": "",
#           "network_matched_filter_snr_upper": null
#         },
#         "gwtc1_gstlal_GW150914": {
#           "data_url": "",
#           "far": 1e-07,
#           "far_lower": null,
#           "far_unit": "yr^-1",
#           "far_upper": null,
#           "network_matched_filter_snr": 24.4,
#           "network_matched_filter_snr_lower": null,
#           "network_matched_filter_snr_unit": "",
#           "network_matched_filter_snr_upper": null
#         },
#         "gwtc1_pe_GW150914": {
#           "E_rad": 3.1,
#           "E_rad_lower": -0.4,
#           "E_rad_unit": "M_sun c^2",
#           "E_rad_upper": 0.4,
#           "L_peak": 3.6,
#           "L_peak_lower": -0.4,
#           "L_peak_unit": "10^56 erg s^-1",
#           "L_peak_upper": 0.4,
#           "a_final": 0.69,
#           "a_final_lower": -0.04,
#           "a_final_unit": "",
#           "a_final_upper": 0.05,
#           "chi_eff": -0.01,
#           "chi_eff_lower": -0.13,
#           "chi_eff_unit": "",
#           "chi_eff_upper": 0.12,
#           "chirp_mass_source": 28.6,
#           "chirp_mass_source_lower": -1.5,
#           "chirp_mass_source_unit": "M_sun",
#           "chirp_mass_source_upper": 1.7,
#           "data_url": "https://dcc.ligo.org/public/0157/P1800370/005/GW150914_GWTC-1.hdf5",
#           "final_mass_source": 63.1,
#           "final_mass_source_lower": -3.0,
#           "final_mass_source_unit": "M_sun",
#           "final_mass_source_upper": 3.4,
#           "geocent_time": 1126259462.4,
#           "geocent_time_lower": null,
#           "geocent_time_unit": "",
#           "geocent_time_upper": null,
#           "luminosity_distance": 440.0,
#           "luminosity_distance_lower": -170.0,
#           "luminosity_distance_unit": "Mpc",
#           "luminosity_distance_upper": 150.0,
#           "mass_1_source": 35.6,
#           "mass_1_source_lower": -3.1,
#           "mass_1_source_unit": "M_sun",
#           "mass_1_source_upper": 4.7,
#           "mass_2_source": 30.6,
#           "mass_2_source_lower": -4.4,
#           "mass_2_source_unit": "M_sun",
#           "mass_2_source_upper": 3.0,
#           "redshift": 0.09,
#           "redshift_lower": -0.03,
#           "redshift_unit": "",
#           "redshift_upper": 0.03,
#           "sky_size": 182.0,
#           "sky_size_lower": null,
#           "sky_size_unit": "deg^2",
#           "sky_size_upper": null
#         },
#         "gwtc1_pycbc_GW150914": {
#           "data_url": "",
#           "far": 1.5300000000000003e-05,
#           "far_lower": null,
#           "far_unit": "yr^-1",
#           "far_upper": null,
#           "network_matched_filter_snr": 23.6,
#           "network_matched_filter_snr_lower": null,
#           "network_matched_filter_snr_unit": "",
#           "network_matched_filter_snr_upper": null
#         }
#       },
#       "redshift": 0.09,
#       "redshift_lower": -0.03,
#       "redshift_unit": "",
#       "redshift_upper": 0.03,
#       "reference": "https://doi.org/10.7935/82H3-HH23",
#       "strain": [
#         {
#           "GPSstart": 1126259447,
#           "detector": "H1",
#           "duration": 32,
#           "format": "gwf",
#           "sampling_rate": 16384,
#           "url": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126259447-32.gwf"
#         },
#         {
#           "GPSstart": 1126259447,
#           "detector": "H1",
#           "duration": 32,
#           "format": "hdf5",
#           "sampling_rate": 16384,
#           "url": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126259447-32.hdf5"
#         },
#         {
#           "GPSstart": 1126259447,
#           "detector": "H1",
#           "duration": 32,
#           "format": "txt",
#           "sampling_rate": 16384,
#           "url": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126259447-32.txt.gz"
#         },
#         {
#           "GPSstart": 1126259447,
#           "detector": "H1",
#           "duration": 32,
#           "format": "gwf",
#           "sampling_rate": 4096,
#           "url": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126259447-32.gwf"
#         },
#         {
#           "GPSstart": 1126259447,
#           "detector": "H1",
#           "duration": 32,
#           "format": "hdf5",
#           "sampling_rate": 4096,
#           "url": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126259447-32.hdf5"
#         },
#         {
#           "GPSstart": 1126259447,
#           "detector": "H1",
#           "duration": 32,
#           "format": "txt",
#           "sampling_rate": 4096,
#           "url": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126259447-32.txt.gz"
#         },
#         {
#           "GPSstart": 1126257415,
#           "detector": "H1",
#           "duration": 4096,
#           "format": "gwf",
#           "sampling_rate": 16384,
#           "url": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126257415-4096.gwf"
#         },
#         {
#           "GPSstart": 1126257415,
#           "detector": "H1",
#           "duration": 4096,
#           "format": "hdf5",
#           "sampling_rate": 16384,
#           "url": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126257415-4096.hdf5"
#         },
#         {
#           "GPSstart": 1126257415,
#           "detector": "H1",
#           "duration": 4096,
#           "format": "txt",
#           "sampling_rate": 16384,
#           "url": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126257415-4096.txt.gz"
#         },
#         {
#           "GPSstart": 1126257415,
#           "detector": "H1",
#           "duration": 4096,
#           "format": "gwf",
#           "sampling_rate": 4096,
#           "url": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126257415-4096.gwf"
#         },
#         {
#           "GPSstart": 1126257415,
#           "detector": "H1",
#           "duration": 4096,
#           "format": "hdf5",
#           "sampling_rate": 4096,
#           "url": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126257415-4096.hdf5"
#         },
#         {
#           "GPSstart": 1126257415,
#           "detector": "H1",
#           "duration": 4096,
#           "format": "txt",
#           "sampling_rate": 4096,
#           "url": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126257415-4096.txt.gz"
#         },
#         {
#           "GPSstart": 1126259447,
#           "detector": "L1",
#           "duration": 32,
#           "format": "gwf",
#           "sampling_rate": 16384,
#           "url": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126259447-32.gwf"
#         },
#         {
#           "GPSstart": 1126259447,
#           "detector": "L1",
#           "duration": 32,
#           "format": "hdf5",
#           "sampling_rate": 16384,
#           "url": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126259447-32.hdf5"
#         },
#         {
#           "GPSstart": 1126259447,
#           "detector": "L1",
#           "duration": 32,
#           "format": "txt",
#           "sampling_rate": 16384,
#           "url": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126259447-32.txt.gz"
#         },
#         {
#           "GPSstart": 1126259447,
#           "detector": "L1",
#           "duration": 32,
#           "format": "gwf",
#           "sampling_rate": 4096,
#           "url": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126259447-32.gwf"
#         },
#         {
#           "GPSstart": 1126259447,
#           "detector": "L1",
#           "duration": 32,
#           "format": "hdf5",
#           "sampling_rate": 4096,
#           "url": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126259447-32.hdf5"
#         },
#         {
#           "GPSstart": 1126259447,
#           "detector": "L1",
#           "duration": 32,
#           "format": "txt",
#           "sampling_rate": 4096,
#           "url": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126259447-32.txt.gz"
#         },
#         {
#           "GPSstart": 1126257415,
#           "detector": "L1",
#           "duration": 4096,
#           "format": "gwf",
#           "sampling_rate": 16384,
#           "url": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126257415-4096.gwf"
#         },
#         {
#           "GPSstart": 1126257415,
#           "detector": "L1",
#           "duration": 4096,
#           "format": "hdf5",
#           "sampling_rate": 16384,
#           "url": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126257415-4096.hdf5"
#         },
#         {
#           "GPSstart": 1126257415,
#           "detector": "L1",
#           "duration": 4096,
#           "format": "txt",
#           "sampling_rate": 16384,
#           "url": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126257415-4096.txt.gz"
#         },
#         {
#           "GPSstart": 1126257415,
#           "detector": "L1",
#           "duration": 4096,
#           "format": "gwf",
#           "sampling_rate": 4096,
#           "url": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126257415-4096.gwf"
#         },
#         {
#           "GPSstart": 1126257415,
#           "detector": "L1",
#           "duration": 4096,
#           "format": "hdf5",
#           "sampling_rate": 4096,
#           "url": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126257415-4096.hdf5"
#         },
#         {
#           "GPSstart": 1126257415,
#           "detector": "L1",
#           "duration": 4096,
#           "format": "txt",
#           "sampling_rate": 4096,
#           "url": "https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126257415-4096.txt.gz"
#         }
#       ],
#       "total_mass_source": null,
#       "total_mass_source_lower": null,
#       "total_mass_source_unit": null,
#       "total_mass_source_upper": null,
#       "version": 3
#     }
#   }
# }

# %%
jsondict = json.loads(r.text)

# %%
jsondict['events']['GW150914-v3']
# Out:
# {'GPS': 1126259462.4,
#  'catalog.shortName': 'GWTC-1-confident',
#  'chi_eff': -0.01,
#  'chi_eff_lower': -0.13,
#  'chi_eff_unit': '',
#  'chi_eff_upper': 0.12,
#  'chirp_mass': None,
#  'chirp_mass_lower': None,
#  'chirp_mass_source': 28.6,
#  'chirp_mass_source_lower': -1.5,
#  'chirp_mass_source_unit': 'M_sun',
#  'chirp_mass_source_upper': 1.7,
#  'chirp_mass_unit': None,
#  'chirp_mass_upper': None,
#  'commonName': 'GW150914',
#  'far': 1e-07,
#  'far_lower': None,
#  'far_unit': 'yr^-1',
#  'far_upper': None,
#  'final_mass_source': 63.1,
#  'final_mass_source_lower': -3.0,
#  'final_mass_source_unit': 'M_sun',
#  'final_mass_source_upper': 3.4,
#  'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3',
#  'luminosity_distance': 440.0,
#  'luminosity_distance_lower': -170.0,
#  'luminosity_distance_unit': 'Mpc',
#  'luminosity_distance_upper': 150.0,
#  'mass_1_source': 35.6,
#  'mass_1_source_lower': -3.1,
#  'mass_1_source_unit': 'M_sun',
#  'mass_1_source_upper': 4.7,
#  'mass_2_source': 30.6,
#  'mass_2_source_lower': -4.4,
#  'mass_2_source_unit': 'M_sun',
#  'mass_2_source_upper': 3.0,
#  'network_matched_filter_snr': 24.4,
#  'network_matched_filter_snr_lower': None,
#  'network_matched_filter_snr_unit': '',
#  'network_matched_filter_snr_upper': None,
#  'parameters': {'gwtc1_cwb_GW150914': {'data_url': '',
#    'far': 0.000163,
#    'far_lower': None,
#    'far_unit': 'yr^-1',
#    'far_upper': None,
#    'network_matched_filter_snr': 25.2,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None},
#   'gwtc1_gstlal_GW150914': {'data_url': '',
#    'far': 1e-07,
#    'far_lower': None,
#    'far_unit': 'yr^-1',
#    'far_upper': None,
#    'network_matched_filter_snr': 24.4,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None},
#   'gwtc1_pe_GW150914': {'E_rad': 3.1,
#    'E_rad_lower': -0.4,
#    'E_rad_unit': 'M_sun c^2',
#    'E_rad_upper': 0.4,
#    'L_peak': 3.6,
#    'L_peak_lower': -0.4,
#    'L_peak_unit': '10^56 erg s^-1',
#    'L_peak_upper': 0.4,
#    'a_final': 0.69,
#    'a_final_lower': -0.04,
#    'a_final_unit': '',
#    'a_final_upper': 0.05,
#    'chi_eff': -0.01,
#    'chi_eff_lower': -0.13,
#    'chi_eff_unit': '',
#    'chi_eff_upper': 0.12,
#    'chirp_mass_source': 28.6,
#    'chirp_mass_source_lower': -1.5,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass_source_upper': 1.7,
#    'data_url': 'https://dcc.ligo.org/public/0157/P1800370/005/GW150914_GWTC-1.hdf5',
#    'final_mass_source': 63.1,
#    'final_mass_source_lower': -3.0,
#    'final_mass_source_unit': 'M_sun',
#    'final_mass_source_upper': 3.4,
#    'geocent_time': 1126259462.4,
#    'geocent_time_lower': None,
#    'geocent_time_unit': '',
#    'geocent_time_upper': None,
#    'luminosity_distance': 440.0,
#    'luminosity_distance_lower': -170.0,
#    'luminosity_distance_unit': 'Mpc',
#    'luminosity_distance_upper': 150.0,
#    'mass_1_source': 35.6,
#    'mass_1_source_lower': -3.1,
#    'mass_1_source_unit': 'M_sun',
#    'mass_1_source_upper': 4.7,
#    'mass_2_source': 30.6,
#    'mass_2_source_lower': -4.4,
#    'mass_2_source_unit': 'M_sun',
#    'mass_2_source_upper': 3.0,
#    'redshift': 0.09,
#    'redshift_lower': -0.03,
#    'redshift_unit': '',
#    'redshift_upper': 0.03,
#    'sky_size': 182.0,
#    'sky_size_lower': None,
#    'sky_size_unit': 'deg^2',
#    'sky_size_upper': None},
#   'gwtc1_pycbc_GW150914': {'data_url': '',
#    'far': 1.5300000000000003e-05,
#    'far_lower': None,
#    'far_unit': 'yr^-1',
#    'far_upper': None,
#    'network_matched_filter_snr': 23.6,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None}},
#  'redshift': 0.09,
#  'redshift_lower': -0.03,
#  'redshift_unit': '',
#  'redshift_upper': 0.03,
#  'reference': 'https://doi.org/10.7935/82H3-HH23',
#  'strain': [{'GPSstart': 1126259447,
#    'detector': 'H1',
#    'duration': 32,
#    'format': 'gwf',
#    'sampling_rate': 16384,
#    'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126259447-32.gwf'},
#   {'GPSstart': 1126259447,
#    'detector': 'H1',
#    'duration': 32,
#    'format': 'hdf5',
#    'sampling_rate': 16384,
#    'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126259447-32.hdf5'},
#   {'GPSstart': 1126259447,
#    'detector': 'H1',
#    'duration': 32,
#    'format': 'txt',
#    'sampling_rate': 16384,
#    'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126259447-32.txt.gz'},
#   {'GPSstart': 1126259447,
#    'detector': 'H1',
#    'duration': 32,
#    'format': 'gwf',
#    'sampling_rate': 4096,
#    'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126259447-32.gwf'},
#   {'GPSstart': 1126259447,
#    'detector': 'H1',
#    'duration': 32,
#    'format': 'hdf5',
#    'sampling_rate': 4096,
#    'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126259447-32.hdf5'},
#   {'GPSstart': 1126259447,
#    'detector': 'H1',
#    'duration': 32,
#    'format': 'txt',
#    'sampling_rate': 4096,
#    'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126259447-32.txt.gz'},
#   {'GPSstart': 1126257415,
#    'detector': 'H1',
#    'duration': 4096,
#    'format': 'gwf',
#    'sampling_rate': 16384,
#    'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126257415-4096.gwf'},
#   {'GPSstart': 1126257415,
#    'detector': 'H1',
#    'duration': 4096,
#    'format': 'hdf5',
#    'sampling_rate': 16384,
#    'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126257415-4096.hdf5'},
#   {'GPSstart': 1126257415,
#    'detector': 'H1',
#    'duration': 4096,
#    'format': 'txt',
#    'sampling_rate': 16384,
#    'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126257415-4096.txt.gz'},
#   {'GPSstart': 1126257415,
#    'detector': 'H1',
#    'duration': 4096,
#    'format': 'gwf',
#    'sampling_rate': 4096,
#    'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126257415-4096.gwf'},
#   {'GPSstart': 1126257415,
#    'detector': 'H1',
#    'duration': 4096,
#    'format': 'hdf5',
#    'sampling_rate': 4096,
#    'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126257415-4096.hdf5'},
#   {'GPSstart': 1126257415,
#    'detector': 'H1',
#    'duration': 4096,
#    'format': 'txt',
#    'sampling_rate': 4096,
#    'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126257415-4096.txt.gz'},
#   {'GPSstart': 1126259447,
#    'detector': 'L1',
#    'duration': 32,
#    'format': 'gwf',
#    'sampling_rate': 16384,
#    'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126259447-32.gwf'},
#   {'GPSstart': 1126259447,
#    'detector': 'L1',
#    'duration': 32,
#    'format': 'hdf5',
#    'sampling_rate': 16384,
#    'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126259447-32.hdf5'},
#   {'GPSstart': 1126259447,
#    'detector': 'L1',
#    'duration': 32,
#    'format': 'txt',
#    'sampling_rate': 16384,
#    'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126259447-32.txt.gz'},
#   {'GPSstart': 1126259447,
#    'detector': 'L1',
#    'duration': 32,
#    'format': 'gwf',
#    'sampling_rate': 4096,
#    'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126259447-32.gwf'},
#   {'GPSstart': 1126259447,
#    'detector': 'L1',
#    'duration': 32,
#    'format': 'hdf5',
#    'sampling_rate': 4096,
#    'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126259447-32.hdf5'},
#   {'GPSstart': 1126259447,
#    'detector': 'L1',
#    'duration': 32,
#    'format': 'txt',
#    'sampling_rate': 4096,
#    'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126259447-32.txt.gz'},
#   {'GPSstart': 1126257415,
#    'detector': 'L1',
#    'duration': 4096,
#    'format': 'gwf',
#    'sampling_rate': 16384,
#    'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126257415-4096.gwf'},
#   {'GPSstart': 1126257415,
#    'detector': 'L1',
#    'duration': 4096,
#    'format': 'hdf5',
#    'sampling_rate': 16384,
#    'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126257415-4096.hdf5'},
#   {'GPSstart': 1126257415,
#    'detector': 'L1',
#    'duration': 4096,
#    'format': 'txt',
#    'sampling_rate': 16384,
#    'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126257415-4096.txt.gz'},
#   {'GPSstart': 1126257415,
#    'detector': 'L1',
#    'duration': 4096,
#    'format': 'gwf',
#    'sampling_rate': 4096,
#    'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126257415-4096.gwf'},
#   {'GPSstart': 1126257415,
#    'detector': 'L1',
#    'duration': 4096,
#    'format': 'hdf5',
#    'sampling_rate': 4096,
#    'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126257415-4096.hdf5'},
#   {'GPSstart': 1126257415,
#    'detector': 'L1',
#    'duration': 4096,
#    'format': 'txt',
#    'sampling_rate': 4096,
#    'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126257415-4096.txt.gz'}],
#  'total_mass_source': None,
#  'total_mass_source_lower': None,
#  'total_mass_source_unit': None,
#  'total_mass_source_upper': None,
#  'version': 3}

# %%
jsondict['events']['GW150914-v3']['mass_1_source'], jsondict['events']['GW150914-v3']['mass_2_source']
# Out:
# (35.6, 30.6)

# %%
jsondict['events']['GW150914-v3']['strain']
# Out:
# [{'GPSstart': 1126259447,
#   'detector': 'H1',
#   'duration': 32,
#   'format': 'gwf',
#   'sampling_rate': 16384,
#   'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126259447-32.gwf'},
#  {'GPSstart': 1126259447,
#   'detector': 'H1',
#   'duration': 32,
#   'format': 'hdf5',
#   'sampling_rate': 16384,
#   'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126259447-32.hdf5'},
#  {'GPSstart': 1126259447,
#   'detector': 'H1',
#   'duration': 32,
#   'format': 'txt',
#   'sampling_rate': 16384,
#   'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126259447-32.txt.gz'},
#  {'GPSstart': 1126259447,
#   'detector': 'H1',
#   'duration': 32,
#   'format': 'gwf',
#   'sampling_rate': 4096,
#   'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126259447-32.gwf'},
#  {'GPSstart': 1126259447,
#   'detector': 'H1',
#   'duration': 32,
#   'format': 'hdf5',
#   'sampling_rate': 4096,
#   'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126259447-32.hdf5'},
#  {'GPSstart': 1126259447,
#   'detector': 'H1',
#   'duration': 32,
#   'format': 'txt',
#   'sampling_rate': 4096,
#   'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126259447-32.txt.gz'},
#  {'GPSstart': 1126257415,
#   'detector': 'H1',
#   'duration': 4096,
#   'format': 'gwf',
#   'sampling_rate': 16384,
#   'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126257415-4096.gwf'},
#  {'GPSstart': 1126257415,
#   'detector': 'H1',
#   'duration': 4096,
#   'format': 'hdf5',
#   'sampling_rate': 16384,
#   'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126257415-4096.hdf5'},
#  {'GPSstart': 1126257415,
#   'detector': 'H1',
#   'duration': 4096,
#   'format': 'txt',
#   'sampling_rate': 16384,
#   'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126257415-4096.txt.gz'},
#  {'GPSstart': 1126257415,
#   'detector': 'H1',
#   'duration': 4096,
#   'format': 'gwf',
#   'sampling_rate': 4096,
#   'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126257415-4096.gwf'},
#  {'GPSstart': 1126257415,
#   'detector': 'H1',
#   'duration': 4096,
#   'format': 'hdf5',
#   'sampling_rate': 4096,
#   'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126257415-4096.hdf5'},
#  {'GPSstart': 1126257415,
#   'detector': 'H1',
#   'duration': 4096,
#   'format': 'txt',
#   'sampling_rate': 4096,
#   'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126257415-4096.txt.gz'},
#  {'GPSstart': 1126259447,
#   'detector': 'L1',
#   'duration': 32,
#   'format': 'gwf',
#   'sampling_rate': 16384,
#   'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126259447-32.gwf'},
#  {'GPSstart': 1126259447,
#   'detector': 'L1',
#   'duration': 32,
#   'format': 'hdf5',
#   'sampling_rate': 16384,
#   'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126259447-32.hdf5'},
#  {'GPSstart': 1126259447,
#   'detector': 'L1',
#   'duration': 32,
#   'format': 'txt',
#   'sampling_rate': 16384,
#   'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126259447-32.txt.gz'},
#  {'GPSstart': 1126259447,
#   'detector': 'L1',
#   'duration': 32,
#   'format': 'gwf',
#   'sampling_rate': 4096,
#   'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126259447-32.gwf'},
#  {'GPSstart': 1126259447,
#   'detector': 'L1',
#   'duration': 32,
#   'format': 'hdf5',
#   'sampling_rate': 4096,
#   'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126259447-32.hdf5'},
#  {'GPSstart': 1126259447,
#   'detector': 'L1',
#   'duration': 32,
#   'format': 'txt',
#   'sampling_rate': 4096,
#   'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126259447-32.txt.gz'},
#  {'GPSstart': 1126257415,
#   'detector': 'L1',
#   'duration': 4096,
#   'format': 'gwf',
#   'sampling_rate': 16384,
#   'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126257415-4096.gwf'},
#  {'GPSstart': 1126257415,
#   'detector': 'L1',
#   'duration': 4096,
#   'format': 'hdf5',
#   'sampling_rate': 16384,
#   'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126257415-4096.hdf5'},
#  {'GPSstart': 1126257415,
#   'detector': 'L1',
#   'duration': 4096,
#   'format': 'txt',
#   'sampling_rate': 16384,
#   'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126257415-4096.txt.gz'},
#  {'GPSstart': 1126257415,
#   'detector': 'L1',
#   'duration': 4096,
#   'format': 'gwf',
#   'sampling_rate': 4096,
#   'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126257415-4096.gwf'},
#  {'GPSstart': 1126257415,
#   'detector': 'L1',
#   'duration': 4096,
#   'format': 'hdf5',
#   'sampling_rate': 4096,
#   'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126257415-4096.hdf5'},
#  {'GPSstart': 1126257415,
#   'detector': 'L1',
#   'duration': 4096,
#   'format': 'txt',
#   'sampling_rate': 4096,
#   'url': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126257415-4096.txt.gz'}]

# %%
hdffiles = [file['url'] for file in jsondict['events']['GW150914-v3']['strain']
                        if file['duration'] == 32 and file['sampling_rate'] == 4096
                                                  and file['format'] == 'hdf5']

# %%
hdffiles
# Out:
# ['https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126259447-32.hdf5',
#  'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126259447-32.hdf5']

# %%
def dump(url, filename):
    r = requests.get(url)
    
    with open(filename, 'wb') as outfile:
        outfile.write(r.content)

# %%
for hdffile in hdffiles:
    dump(hdffile, os.path.basename(hdffile))

# %%
# in case of network trouble, copies of these files can be found in the folder "cache"

# %%
r = requests.get('https://www.gw-openscience.org/eventapi/json/query/show',
                 params={'min-mass-1-source': 50, 'min-mass-2-source': 30})

# %%
json.loads(r.text)
# Out:
# {'events': {'GW170729-v1': {'GPS': 1185389807.3,
#    'catalog.shortName': 'GWTC-1-confident',
#    'chi_eff': 0.37,
#    'chi_eff_lower': -0.25,
#    'chi_eff_unit': '',
#    'chi_eff_upper': 0.21,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': 35.4,
#    'chirp_mass_source_lower': -4.8,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass_source_upper': 6.5,
#    'chirp_mass_unit': None,
#    'chirp_mass_upper': None,
#    'commonName': 'GW170729',
#    'far': 0.02,
#    'far_lower': None,
#    'far_unit': 'yr^-1',
#    'far_upper': None,
#    'final_mass_source': 79.5,
#    'final_mass_source_lower': -10.2,
#    'final_mass_source_unit': 'M_sun',
#    'final_mass_source_upper': 14.7,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW170729/v1',
#    'luminosity_distance': 2840.0,
#    'luminosity_distance_lower': -1360.0,
#    'luminosity_distance_unit': 'Mpc',
#    'luminosity_distance_upper': 1400.0,
#    'mass_1_source': 50.2,
#    'mass_1_source_lower': -10.2,
#    'mass_1_source_unit': 'M_sun',
#    'mass_1_source_upper': 16.2,
#    'mass_2_source': 34.0,
#    'mass_2_source_lower': -10.1,
#    'mass_2_source_unit': 'M_sun',
#    'mass_2_source_upper': 9.1,
#    'network_matched_filter_snr': 10.2,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'redshift': 0.49,
#    'redshift_lower': -0.21,
#    'redshift_unit': '',
#    'redshift_upper': 0.19,
#    'reference': 'https://doi.org/10.7935/82H3-HH23',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   'GW190519_153544-v1': {'GPS': 1242315362.4,
#    'catalog.shortName': 'GWTC-2',
#    'chi_eff': 0.31,
#    'chi_eff_lower': -0.22,
#    'chi_eff_unit': '',
#    'chi_eff_upper': 0.2,
#    'chirp_mass': 65.1,
#    'chirp_mass_lower': -10.3,
#    'chirp_mass_source': 44.5,
#    'chirp_mass_source_lower': -7.1,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass_source_upper': 6.4,
#    'chirp_mass_unit': 'M_sun',
#    'chirp_mass_upper': 7.7,
#    'commonName': 'GW190519_153544',
#    'far': 1e-05,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': 101.0,
#    'final_mass_source_lower': -13.8,
#    'final_mass_source_unit': 'M_sun',
#    'final_mass_source_upper': 12.4,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-2/GW190519_153544/v1',
#    'luminosity_distance': 2530.0,
#    'luminosity_distance_lower': -920.0,
#    'luminosity_distance_unit': 'Mpc',
#    'luminosity_distance_upper': 1830.0,
#    'mass_1_source': 66.0,
#    'mass_1_source_lower': -12.0,
#    'mass_1_source_unit': 'M_sun',
#    'mass_1_source_upper': 10.7,
#    'mass_2_source': 40.5,
#    'mass_2_source_lower': -11.1,
#    'mass_2_source_unit': 'M_sun',
#    'mass_2_source_upper': 11.0,
#    'network_matched_filter_snr': 12.04985270704691,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'redshift': 0.44,
#    'redshift_lower': -0.14,
#    'redshift_unit': '',
#    'redshift_upper': 0.25,
#    'reference': '/GWTC-2/',
#    'total_mass_source': 106.6,
#    'total_mass_source_lower': -14.8,
#    'total_mass_source_unit': 'M_sun',
#    'total_mass_source_upper': 13.5,
#    'version': 1},
#   'GW190521-v2': {'GPS': 1242442967.4,
#    'catalog.shortName': 'O3_Discovery_Papers',
#    'chi_eff': 0.08,
#    'chi_eff_lower': -0.36,
#    'chi_eff_unit': '',
#    'chi_eff_upper': 0.27,
#    'chirp_mass': 117.0,
#    'chirp_mass_lower': -14.0,
#    'chirp_mass_source': 64.0,
#    'chirp_mass_source_lower': -8.0,
#    'chirp_mass_source_unit': '',
#    'chirp_mass_source_upper': 13.0,
#    'chirp_mass_unit': '',
#    'chirp_mass_upper': 12.0,
#    'commonName': 'GW190521',
#    'far': None,
#    'far_lower': None,
#    'far_unit': None,
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/O3_Discovery_Papers/GW190521/v2',
#    'luminosity_distance': 5300.0,
#    'luminosity_distance_lower': -2600.0,
#    'luminosity_distance_unit': '',
#    'luminosity_distance_upper': 2400.0,
#    'mass_1_source': 85.0,
#    'mass_1_source_lower': -14.0,
#    'mass_1_source_unit': '',
#    'mass_1_source_upper': 21.0,
#    'mass_2_source': 66.0,
#    'mass_2_source_lower': -18.0,
#    'mass_2_source_unit': '',
#    'mass_2_source_upper': 17.0,
#    'network_matched_filter_snr': 14.6,
#    'network_matched_filter_snr_lower': -0.4,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': 0.4,
#    'redshift': 0.82,
#    'redshift_lower': -0.34,
#    'redshift_unit': '',
#    'redshift_upper': 0.28,
#    'reference': '/o3_eventdata_docs/',
#    'total_mass_source': 150.0,
#    'total_mass_source_lower': -17.0,
#    'total_mass_source_unit': '',
#    'total_mass_source_upper': 29.0,
#    'version': 2},
#   'GW190521-v3': {'GPS': 1242442967.4,
#    'catalog.shortName': 'GWTC-2',
#    'chi_eff': 0.03,
#    'chi_eff_lower': -0.39,
#    'chi_eff_unit': '',
#    'chi_eff_upper': 0.32,
#    'chirp_mass': 114.8,
#    'chirp_mass_lower': -17.6,
#    'chirp_mass_source': 69.2,
#    'chirp_mass_source_lower': -10.6,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass_source_upper': 17.0,
#    'chirp_mass_unit': 'M_sun',
#    'chirp_mass_upper': 15.2,
#    'commonName': 'GW190521',
#    'far': 0.0002039635028,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': 156.3,
#    'final_mass_source_lower': -22.4,
#    'final_mass_source_unit': 'M_sun',
#    'final_mass_source_upper': 36.8,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-2/GW190521/v3',
#    'luminosity_distance': 3920.0,
#    'luminosity_distance_lower': -1950.0,
#    'luminosity_distance_unit': 'Mpc',
#    'luminosity_distance_upper': 2190.0,
#    'mass_1_source': 95.3,
#    'mass_1_source_lower': -18.9,
#    'mass_1_source_unit': 'M_sun',
#    'mass_1_source_upper': 28.7,
#    'mass_2_source': 69.0,
#    'mass_2_source_lower': -23.1,
#    'mass_2_source_unit': 'M_sun',
#    'mass_2_source_upper': 22.7,
#    'network_matched_filter_snr': 14.376046048896756,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'redshift': 0.64,
#    'redshift_lower': -0.28,
#    'redshift_unit': '',
#    'redshift_upper': 0.28,
#    'reference': '/GWTC-2/',
#    'total_mass_source': 163.9,
#    'total_mass_source_lower': -23.5,
#    'total_mass_source_unit': 'M_sun',
#    'total_mass_source_upper': 39.2,
#    'version': 3},
#   'GW190602_175927-v1': {'GPS': 1243533585.1,
#    'catalog.shortName': 'GWTC-2',
#    'chi_eff': 0.07,
#    'chi_eff_lower': -0.24,
#    'chi_eff_unit': '',
#    'chi_eff_upper': 0.25,
#    'chirp_mass': 72.9,
#    'chirp_mass_lower': -13.7,
#    'chirp_mass_source': 49.1,
#    'chirp_mass_source_lower': -8.5,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass_source_upper': 9.1,
#    'chirp_mass_unit': 'M_sun',
#    'chirp_mass_upper': 10.8,
#    'commonName': 'GW190602_175927',
#    'far': 1.1478437256536947e-05,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': 110.9,
#    'final_mass_source_lower': -14.9,
#    'final_mass_source_unit': 'M_sun',
#    'final_mass_source_upper': 17.7,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-2/GW190602_175927/v1',
#    'luminosity_distance': 2690.0,
#    'luminosity_distance_lower': -1120.0,
#    'luminosity_distance_unit': 'Mpc',
#    'luminosity_distance_upper': 1790.0,
#    'mass_1_source': 69.1,
#    'mass_1_source_lower': -13.0,
#    'mass_1_source_unit': 'M_sun',
#    'mass_1_source_upper': 15.7,
#    'mass_2_source': 47.8,
#    'mass_2_source_lower': -17.4,
#    'mass_2_source_unit': 'M_sun',
#    'mass_2_source_upper': 14.3,
#    'network_matched_filter_snr': 12.13087548611321,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'redshift': 0.47,
#    'redshift_lower': -0.17,
#    'redshift_unit': '',
#    'redshift_upper': 0.25,
#    'reference': '/GWTC-2/',
#    'total_mass_source': 116.3,
#    'total_mass_source_lower': -15.6,
#    'total_mass_source_unit': 'M_sun',
#    'total_mass_source_upper': 19.0,
#    'version': 1},
#   'GW190620_030421-v1': {'GPS': 1245035079.3,
#    'catalog.shortName': 'GWTC-2',
#    'chi_eff': 0.33,
#    'chi_eff_lower': -0.25,
#    'chi_eff_unit': '',
#    'chi_eff_upper': 0.22,
#    'chirp_mass': 57.5,
#    'chirp_mass_lower': -11.2,
#    'chirp_mass_source': 38.3,
#    'chirp_mass_source_lower': -6.5,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass_source_upper': 8.3,
#    'chirp_mass_unit': 'M_sun',
#    'chirp_mass_upper': 9.0,
#    'commonName': 'GW190620_030421',
#    'far': 0.0029209383726319974,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': 87.2,
#    'final_mass_source_lower': -12.1,
#    'final_mass_source_unit': 'M_sun',
#    'final_mass_source_upper': 16.8,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-2/GW190620_030421/v1',
#    'luminosity_distance': 2810.0,
#    'luminosity_distance_lower': -1310.0,
#    'luminosity_distance_unit': 'Mpc',
#    'luminosity_distance_upper': 1680.0,
#    'mass_1_source': 57.1,
#    'mass_1_source_lower': -12.7,
#    'mass_1_source_unit': 'M_sun',
#    'mass_1_source_upper': 16.0,
#    'mass_2_source': 35.5,
#    'mass_2_source_lower': -12.3,
#    'mass_2_source_unit': 'M_sun',
#    'mass_2_source_upper': 12.2,
#    'network_matched_filter_snr': 10.91846314686192,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'redshift': 0.49,
#    'redshift_lower': -0.2,
#    'redshift_unit': '',
#    'redshift_upper': 0.23,
#    'reference': '/GWTC-2/',
#    'total_mass_source': 92.1,
#    'total_mass_source_lower': -13.1,
#    'total_mass_source_unit': 'M_sun',
#    'total_mass_source_upper': 18.5,
#    'version': 1},
#   'GW190701_203306-v1': {'GPS': 1246048404.6,
#    'catalog.shortName': 'GWTC-2',
#    'chi_eff': -0.07,
#    'chi_eff_lower': -0.29,
#    'chi_eff_unit': '',
#    'chi_eff_upper': 0.23,
#    'chirp_mass': 55.5,
#    'chirp_mass_lower': -8.1,
#    'chirp_mass_source': 40.3,
#    'chirp_mass_source_lower': -4.9,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass_source_upper': 5.4,
#    'chirp_mass_unit': 'M_sun',
#    'chirp_mass_upper': 7.3,
#    'commonName': 'GW190701_203306',
#    'far': 0.010861368605368522,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': 90.2,
#    'final_mass_source_lower': -8.9,
#    'final_mass_source_unit': 'M_sun',
#    'final_mass_source_upper': 11.3,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-2/GW190701_203306/v1',
#    'luminosity_distance': 2060.0,
#    'luminosity_distance_lower': -730.0,
#    'luminosity_distance_unit': 'Mpc',
#    'luminosity_distance_upper': 760.0,
#    'mass_1_source': 53.9,
#    'mass_1_source_lower': -8.0,
#    'mass_1_source_unit': 'M_sun',
#    'mass_1_source_upper': 11.8,
#    'mass_2_source': 40.8,
#    'mass_2_source_lower': -12.0,
#    'mass_2_source_unit': 'M_sun',
#    'mass_2_source_upper': 8.7,
#    'network_matched_filter_snr': 11.58996006414267,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'redshift': 0.37,
#    'redshift_lower': -0.12,
#    'redshift_unit': '',
#    'redshift_upper': 0.11,
#    'reference': '/GWTC-2/',
#    'total_mass_source': 94.3,
#    'total_mass_source_lower': -9.5,
#    'total_mass_source_unit': 'M_sun',
#    'total_mass_source_upper': 12.1,
#    'version': 1},
#   'GW190706_222641-v1': {'GPS': 1246487219.3,
#    'catalog.shortName': 'GWTC-2',
#    'chi_eff': 0.28,
#    'chi_eff_lower': -0.29,
#    'chi_eff_unit': '',
#    'chi_eff_upper': 0.26,
#    'chirp_mass': 75.1,
#    'chirp_mass_lower': -17.5,
#    'chirp_mass_source': 42.7,
#    'chirp_mass_source_lower': -7.0,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass_source_upper': 10.0,
#    'chirp_mass_unit': 'M_sun',
#    'chirp_mass_upper': 11.0,
#    'commonName': 'GW190706_222641',
#    'far': 1e-05,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': 99.0,
#    'final_mass_source_lower': -13.5,
#    'final_mass_source_unit': 'M_sun',
#    'final_mass_source_upper': 18.3,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-2/GW190706_222641/v1',
#    'luminosity_distance': 4420.0,
#    'luminosity_distance_lower': -1930.0,
#    'luminosity_distance_unit': 'Mpc',
#    'luminosity_distance_upper': 2590.0,
#    'mass_1_source': 67.0,
#    'mass_1_source_lower': -16.2,
#    'mass_1_source_unit': 'M_sun',
#    'mass_1_source_upper': 14.6,
#    'mass_2_source': 38.2,
#    'mass_2_source_lower': -13.3,
#    'mass_2_source_unit': 'M_sun',
#    'mass_2_source_upper': 14.6,
#    'network_matched_filter_snr': 12.34834506062684,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'redshift': 0.71,
#    'redshift_lower': -0.27,
#    'redshift_unit': '',
#    'redshift_upper': 0.32,
#    'reference': '/GWTC-2/',
#    'total_mass_source': 104.1,
#    'total_mass_source_lower': -13.9,
#    'total_mass_source_unit': 'M_sun',
#    'total_mass_source_upper': 20.2,
#    'version': 1}}}
