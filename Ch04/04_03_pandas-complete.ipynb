# %% [markdown]
# # 04_03_pandas.ipynb - Data tables with Pandas

# %%
import requests

import numpy as np
import matplotlib.pyplot as pp
import pandas as pd
import astropy.units

# %%
# utility function from the last video

def dump(url, filename):
    r = requests.get(url)
    
    with open(filename, 'wb') as outfile:
        outfile.write(r.content)

# %%
# in case of network problems, you can use the file cache/gwtc-20210726.csv
dump('https://www.gw-openscience.org/eventapi/csv/GWTC', 'gwtc.csv')

# %%
gwtc = pd.read_csv('gwtc.csv')

# %%
gwtc
# Out:
#                     id       commonName  version catalog.shortName  \
# 0          GW150914-v3         GW150914        3  GWTC-1-confident
# 1          GW151012-v3         GW151012        3  GWTC-1-confident
# 2          GW151226-v2         GW151226        2  GWTC-1-confident
# 3          GW170104-v2         GW170104        2  GWTC-1-confident
# 4          GW170608-v3         GW170608        3  GWTC-1-confident
# 5          GW170729-v1         GW170729        1  GWTC-1-confident
# 6          GW170809-v1         GW170809        1  GWTC-1-confident
# 7          GW170814-v3         GW170814        3  GWTC-1-confident
# 8          GW170817-v3         GW170817        3  GWTC-1-confident
# 9          GW170818-v1         GW170818        1  GWTC-1-confident
# 10         GW170823-v1         GW170823        1  GWTC-1-confident
# 11  GW190408_181802-v1  GW190408_181802        1            GWTC-2
# 12         GW190412-v3         GW190412        3            GWTC-2
# 13  GW190413_052954-v1  GW190413_052954        1            GWTC-2
# 14  GW190413_134308-v1  GW190413_134308        1            GWTC-2
# 15  GW190421_213856-v1  GW190421_213856        1            GWTC-2
# 16  GW190424_180648-v1  GW190424_180648        1            GWTC-2
# 17         GW190425-v2         GW190425        2            GWTC-2
# 18  GW190426_152155-v1  GW190426_152155        1            GWTC-2
# 19  GW190503_185404-v1  GW190503_185404        1            GWTC-2
# 20  GW190512_180714-v1  GW190512_180714        1            GWTC-2
# 21  GW190513_205428-v1  GW190513_205428        1            GWTC-2
# 22  GW190514_065416-v1  GW190514_065416        1            GWTC-2
# 23  GW190517_055101-v1  GW190517_055101        1            GWTC-2
# 24  GW190519_153544-v1  GW190519_153544        1            GWTC-2
# 25         GW190521-v3         GW190521        3            GWTC-2
# 26  GW190521_074359-v1  GW190521_074359        1            GWTC-2
# 27  GW190527_092055-v1  GW190527_092055        1            GWTC-2
# 28  GW190602_175927-v1  GW190602_175927        1            GWTC-2
# 29  GW190620_030421-v1  GW190620_030421        1            GWTC-2
# 30  GW190630_185205-v1  GW190630_185205        1            GWTC-2
# 31  GW190701_203306-v1  GW190701_203306        1            GWTC-2
# 32  GW190706_222641-v1  GW190706_222641        1            GWTC-2
# 33  GW190707_093326-v1  GW190707_093326        1            GWTC-2
# 34  GW190708_232457-v1  GW190708_232457        1            GWTC-2
# 35  GW190719_215514-v1  GW190719_215514        1            GWTC-2
# 36  GW190720_000836-v1  GW190720_000836        1            GWTC-2
# 37  GW190727_060333-v1  GW190727_060333        1            GWTC-2
# 38  GW190728_064510-v1  GW190728_064510        1            GWTC-2
# 39  GW190731_140936-v1  GW190731_140936        1            GWTC-2
# 40  GW190803_022701-v1  GW190803_022701        1            GWTC-2
# 41         GW190814-v2         GW190814        2            GWTC-2
# 42  GW190828_063405-v1  GW190828_063405        1            GWTC-2
# 43  GW190828_065509-v1  GW190828_065509        1            GWTC-2
# 44  GW190909_114149-v1  GW190909_114149        1            GWTC-2
# 45  GW190910_112807-v1  GW190910_112807        1            GWTC-2
# 46  GW190915_235702-v1  GW190915_235702        1            GWTC-2
# 47  GW190924_021846-v1  GW190924_021846        1            GWTC-2
# 48  GW190929_012149-v1  GW190929_012149        1            GWTC-2
# 49  GW190930_133541-v1  GW190930_133541        1            GWTC-2
#
#              GPS                          reference  \
# 0   1.126259e+09  https://doi.org/10.7935/82H3-HH23
# 1   1.128679e+09  https://doi.org/10.7935/82H3-HH23
# 2   1.135136e+09  https://doi.org/10.7935/82H3-HH23
# 3   1.167560e+09  https://doi.org/10.7935/82H3-HH23
# 4   1.180922e+09  https://doi.org/10.7935/82H3-HH23
# 5   1.185390e+09  https://doi.org/10.7935/82H3-HH23
# 6   1.186303e+09  https://doi.org/10.7935/82H3-HH23
# 7   1.186742e+09  https://doi.org/10.7935/82H3-HH23
# 8   1.187009e+09  https://doi.org/10.7935/82H3-HH23
# 9   1.187058e+09  https://doi.org/10.7935/82H3-HH23
# 10  1.187529e+09  https://doi.org/10.7935/82H3-HH23
# 11  1.238783e+09                           /GWTC-2/
# 12  1.239082e+09                           /GWTC-2/
# 13  1.239169e+09                           /GWTC-2/
# 14  1.239198e+09                           /GWTC-2/
# 15  1.239918e+09                           /GWTC-2/
# 16  1.240164e+09                           /GWTC-2/
# 17  1.240216e+09                           /GWTC-2/
# 18  1.240327e+09                           /GWTC-2/
# 19  1.240945e+09                           /GWTC-2/
# 20  1.241720e+09                           /GWTC-2/
# 21  1.241816e+09                           /GWTC-2/
# 22  1.241852e+09                           /GWTC-2/
# 23  1.242107e+09                           /GWTC-2/
# 24  1.242315e+09                           /GWTC-2/
# 25  1.242443e+09                           /GWTC-2/
# 26  1.242460e+09                           /GWTC-2/
# 27  1.242984e+09                           /GWTC-2/
# 28  1.243534e+09                           /GWTC-2/
# 29  1.245035e+09                           /GWTC-2/
# 30  1.245956e+09                           /GWTC-2/
# 31  1.246048e+09                           /GWTC-2/
# 32  1.246487e+09                           /GWTC-2/
# 33  1.246527e+09                           /GWTC-2/
# 34  1.246664e+09                           /GWTC-2/
# 35  1.247609e+09                           /GWTC-2/
# 36  1.247617e+09                           /GWTC-2/
# 37  1.248243e+09                           /GWTC-2/
# 38  1.248332e+09                           /GWTC-2/
# 39  1.248617e+09                           /GWTC-2/
# 40  1.248834e+09                           /GWTC-2/
# 41  1.249852e+09                           /GWTC-2/
# 42  1.251009e+09                           /GWTC-2/
# 43  1.251011e+09                           /GWTC-2/
# 44  1.252065e+09                           /GWTC-2/
# 45  1.252150e+09                           /GWTC-2/
# 46  1.252627e+09                           /GWTC-2/
# 47  1.253327e+09                           /GWTC-2/
# 48  1.253755e+09                           /GWTC-2/
# 49  1.253886e+09                           /GWTC-2/
#
#                                               jsonurl  mass_1_source  \
# 0   https://www.gw-openscience.org/eventapi/json/G...          35.60
# 1   https://www.gw-openscience.org/eventapi/json/G...          23.20
# 2   https://www.gw-openscience.org/eventapi/json/G...          13.70
# 3   https://www.gw-openscience.org/eventapi/json/G...          30.80
# 4   https://www.gw-openscience.org/eventapi/json/G...          11.00
# 5   https://www.gw-openscience.org/eventapi/json/G...          50.20
# 6   https://www.gw-openscience.org/eventapi/json/G...          35.00
# 7   https://www.gw-openscience.org/eventapi/json/G...          30.60
# 8   https://www.gw-openscience.org/eventapi/json/G...           1.46
# 9   https://www.gw-openscience.org/eventapi/json/G...          35.40
# 10  https://www.gw-openscience.org/eventapi/json/G...          39.50
# 11  https://www.gw-openscience.org/eventapi/json/G...          24.60
# 12  https://www.gw-openscience.org/eventapi/json/G...          30.10
# 13  https://www.gw-openscience.org/eventapi/json/G...          34.70
# 14  https://www.gw-openscience.org/eventapi/json/G...          47.50
# 15  https://www.gw-openscience.org/eventapi/json/G...          41.30
# 16  https://www.gw-openscience.org/eventapi/json/G...          40.50
# 17  https://www.gw-openscience.org/eventapi/json/G...           2.00
# 18  https://www.gw-openscience.org/eventapi/json/G...           5.70
# 19  https://www.gw-openscience.org/eventapi/json/G...          43.30
# 20  https://www.gw-openscience.org/eventapi/json/G...          23.30
# 21  https://www.gw-openscience.org/eventapi/json/G...          35.70
# 22  https://www.gw-openscience.org/eventapi/json/G...          39.00
# 23  https://www.gw-openscience.org/eventapi/json/G...          37.40
# 24  https://www.gw-openscience.org/eventapi/json/G...          66.00
# 25  https://www.gw-openscience.org/eventapi/json/G...          95.30
# 26  https://www.gw-openscience.org/eventapi/json/G...          42.20
# 27  https://www.gw-openscience.org/eventapi/json/G...          36.50
# 28  https://www.gw-openscience.org/eventapi/json/G...          69.10
# 29  https://www.gw-openscience.org/eventapi/json/G...          57.10
# 30  https://www.gw-openscience.org/eventapi/json/G...          35.10
# 31  https://www.gw-openscience.org/eventapi/json/G...          53.90
# 32  https://www.gw-openscience.org/eventapi/json/G...          67.00
# 33  https://www.gw-openscience.org/eventapi/json/G...          11.60
# 34  https://www.gw-openscience.org/eventapi/json/G...          17.60
# 35  https://www.gw-openscience.org/eventapi/json/G...          36.50
# 36  https://www.gw-openscience.org/eventapi/json/G...          13.40
# 37  https://www.gw-openscience.org/eventapi/json/G...          38.00
# 38  https://www.gw-openscience.org/eventapi/json/G...          12.30
# 39  https://www.gw-openscience.org/eventapi/json/G...          41.50
# 40  https://www.gw-openscience.org/eventapi/json/G...          37.30
# 41  https://www.gw-openscience.org/eventapi/json/G...          23.20
# 42  https://www.gw-openscience.org/eventapi/json/G...          32.10
# 43  https://www.gw-openscience.org/eventapi/json/G...          24.10
# 44  https://www.gw-openscience.org/eventapi/json/G...          45.80
# 45  https://www.gw-openscience.org/eventapi/json/G...          43.90
# 46  https://www.gw-openscience.org/eventapi/json/G...          35.30
# 47  https://www.gw-openscience.org/eventapi/json/G...           8.90
# 48  https://www.gw-openscience.org/eventapi/json/G...          80.80
# 49  https://www.gw-openscience.org/eventapi/json/G...          12.30
#
#     mass_1_source_lower  mass_1_source_upper  ...  chirp_mass_upper  redshift  \
# 0                  -3.1                 4.70  ...               NaN      0.09
# 1                  -5.5                14.90  ...               NaN      0.21
# 2                  -3.2                 8.80  ...               NaN      0.09
# 3                  -5.6                 7.30  ...               NaN      0.20
# 4                  -1.7                 5.50  ...               NaN      0.07
# 5                 -10.2                16.20  ...               NaN      0.49
# 6                  -5.9                 8.30  ...               NaN      0.20
# 7                  -3.0                 5.60  ...               NaN      0.12
# 8                  -0.1                 0.12  ...               NaN      0.01
# 9                  -4.7                 7.50  ...               NaN      0.21
# 10                 -6.7                11.20  ...               NaN      0.35
# 11                 -3.4                 5.10  ...            1.4000      0.29
# 12                 -5.1                 4.70  ...            0.2000      0.15
# 13                 -8.1                12.60  ...            7.7000      0.59
# 14                -10.7                13.50  ...            8.6000      0.71
# 15                 -6.9                10.40  ...            6.6000      0.49
# 16                 -7.3                11.10  ...            6.0000      0.39
# 17                 -0.3                 0.60  ...            0.0008      0.03
# 18                 -2.3                 3.90  ...            0.0100      0.08
# 19                 -8.1                 9.20  ...            5.3000      0.27
# 20                 -5.8                 5.30  ...            0.9000      0.27
# 21                 -9.2                 9.50  ...            5.6000      0.37
# 22                 -8.2                14.70  ...            7.5000      0.67
# 23                 -7.6                11.70  ...            4.0000      0.34
# 24                -12.0                10.70  ...            7.7000      0.44
# 25                -18.9                28.70  ...           15.2000      0.64
# 26                 -4.8                 5.90  ...            2.2000      0.24
# 27                 -9.0                16.40  ...           21.7000      0.44
# 28                -13.0                15.70  ...           10.8000      0.47
# 29                -12.7                16.00  ...            9.0000      0.49
# 30                 -5.6                 6.90  ...            1.6000      0.18
# 31                 -8.0                11.80  ...            7.3000      0.37
# 32                -16.2                14.60  ...           11.0000      0.71
# 33                 -1.7                 3.30  ...            0.1000      0.16
# 34                 -2.3                 4.70  ...            0.3000      0.18
# 35                -10.3                18.00  ...            9.2000      0.64
# 36                 -3.0                 6.70  ...            0.2000      0.16
# 37                 -6.2                 9.50  ...            5.3000      0.55
# 38                 -2.2                 7.20  ...            0.0900      0.18
# 39                 -9.0                12.20  ...            6.8000      0.55
# 40                 -7.0                10.60  ...            6.3000      0.55
# 41                 -1.0                 1.10  ...            0.0200      0.05
# 42                 -4.0                 5.80  ...            2.9000      0.38
# 43                 -7.2                 7.00  ...            0.6000      0.30
# 44                -13.3                52.70  ...           32.2000      0.62
# 45                 -6.1                 7.60  ...            4.6000      0.28
# 46                 -6.4                 9.50  ...            3.3000      0.30
# 47                 -2.0                 7.00  ...            0.0400      0.12
# 48                -33.2                33.00  ...           19.9000      0.38
# 49                 -2.3                12.40  ...            0.2000      0.15
#
#     redshift_lower  redshift_upper           far  far_lower  far_upper  \
# 0            -0.03           0.030  1.000000e-07        NaN        NaN
# 1            -0.09           0.090  7.920000e-03        NaN        NaN
# 2            -0.04           0.040  1.000000e-07        NaN        NaN
# 3            -0.08           0.080  1.000000e-07        NaN        NaN
# 4            -0.02           0.020  1.000000e-07        NaN        NaN
# 5            -0.21           0.190  2.000000e-02        NaN        NaN
# 6            -0.07           0.050  1.000000e-07        NaN        NaN
# 7            -0.04           0.030  1.000000e-07        NaN        NaN
# 8            -0.00           0.000  1.000000e-07        NaN        NaN
# 9            -0.07           0.070  4.200000e-05        NaN        NaN
# 10           -0.15           0.150  1.000000e-07        NaN        NaN
# 11           -0.10           0.060  1.000000e-05        NaN        NaN
# 12           -0.03           0.030  1.000000e-05        NaN        NaN
# 13           -0.24           0.290  7.168327e-02        NaN        NaN
# 14           -0.30           0.310  4.365732e-02        NaN        NaN
# 15           -0.21           0.190  7.738314e-04        NaN        NaN
# 16           -0.19           0.230  7.822865e-01        NaN        NaN
# 17           -0.02           0.010  7.518547e-04        NaN        NaN
# 18           -0.03           0.040  1.443741e+00        NaN        NaN
# 19           -0.11           0.110  1.000000e-05        NaN        NaN
# 20           -0.10           0.090  1.000000e-05        NaN        NaN
# 21           -0.13           0.130  1.000000e-05        NaN        NaN
# 22           -0.31           0.330  5.266877e-01        NaN        NaN
# 23           -0.14           0.240  5.720514e-05        NaN        NaN
# 24           -0.14           0.250  1.000000e-05        NaN        NaN
# 25           -0.28           0.280  2.039635e-04        NaN        NaN
# 26           -0.10           0.070  1.000000e-05        NaN        NaN
# 27           -0.20           0.340  6.227035e-02        NaN        NaN
# 28           -0.17           0.250  1.147844e-05        NaN        NaN
# 29           -0.20           0.230  2.920938e-03        NaN        NaN
# 30           -0.07           0.100  1.000000e-05        NaN        NaN
# 31           -0.12           0.110  1.086137e-02        NaN        NaN
# 32           -0.27           0.320  1.000000e-05        NaN        NaN
# 33           -0.07           0.070  1.000000e-05        NaN        NaN
# 34           -0.07           0.060  2.825251e-05        NaN        NaN
# 35           -0.29           0.330  1.559222e+00        NaN        NaN
# 36           -0.06           0.120  1.000000e-05        NaN        NaN
# 37           -0.22           0.210  1.000000e-05        NaN        NaN
# 38           -0.07           0.050  1.000000e-05        NaN        NaN
# 39           -0.26           0.310  2.058421e-01        NaN        NaN
# 40           -0.24           0.260  2.693432e-02        NaN        NaN
# 41           -0.01           0.009  1.000000e-05        NaN        NaN
# 42           -0.15           0.100  1.000000e-05        NaN        NaN
# 43           -0.10           0.100  1.000000e-05        NaN        NaN
# 44           -0.33           0.410  1.111228e+00        NaN        NaN
# 45           -0.10           0.160  1.885269e-05        NaN        NaN
# 46           -0.10           0.110  1.000000e-05        NaN        NaN
# 47           -0.04           0.040  1.000000e-05        NaN        NaN
# 48           -0.17           0.490  2.016144e-02        NaN        NaN
# 49           -0.06           0.060  3.309220e-02        NaN        NaN
#
#     final_mass_source  final_mass_source_lower  final_mass_source_upper
# 0                63.1                     -3.0                      3.4
# 1                35.6                     -3.8                     10.8
# 2                20.5                     -1.5                      6.4
# 3                48.9                     -4.0                      5.1
# 4                17.8                     -0.7                      3.4
# 5                79.5                    -10.2                     14.7
# 6                56.3                     -3.8                      5.2
# 7                53.2                     -2.4                      3.2
# 8                 2.8                      NaN                      NaN
# 9                59.4                     -3.8                      4.9
# 10               65.4                     -7.4                     10.1
# 11               41.1                     -2.8                      3.9
# 12               37.3                     -3.8                      3.9
# 13               56.0                     -9.2                     12.5
# 14               75.5                    -11.4                     16.4
# 15               69.7                     -8.7                     12.5
# 16               68.9                    -10.1                     12.4
# 17                NaN                      NaN                      NaN
# 18                NaN                      NaN                      NaN
# 19               68.6                     -7.7                      8.8
# 20               34.5                     -3.5                      3.8
# 21               51.6                     -5.8                      8.2
# 22               64.5                    -10.4                     17.9
# 23               59.3                     -8.9                      9.1
# 24              101.0                    -13.8                     12.4
# 25              156.3                    -22.4                     36.8
# 26               71.0                     -4.4                      6.5
# 27               56.4                     -9.3                     20.2
# 28              110.9                    -14.9                     17.7
# 29               87.2                    -12.1                     16.8
# 30               56.4                     -4.6                      4.4
# 31               90.2                     -8.9                     11.3
# 32               99.0                    -13.5                     18.3
# 33               19.2                     -1.3                      1.9
# 34               29.5                     -1.8                      2.5
# 35               54.9                    -10.2                     17.3
# 36               20.4                     -2.2                      4.5
# 37               63.8                     -7.5                     10.9
# 38               19.6                     -1.3                      4.7
# 39               67.0                    -10.8                     14.6
# 40               61.7                     -8.5                     11.8
# 41               25.6                     -0.9                      1.1
# 42               54.9                     -4.3                      7.2
# 43               33.1                     -4.5                      5.5
# 44               72.0                    -16.8                     54.9
# 45               75.8                     -8.6                      8.5
# 46               57.2                     -6.0                      7.1
# 47               13.3                     -1.0                      5.2
# 48              101.5                    -25.3                     33.6
# 49               19.4                     -1.5                      9.2
#
# [50 rows x 40 columns]

# %%
gwtc.head()
# Out:
#             id commonName  version catalog.shortName           GPS  \
# 0  GW150914-v3   GW150914        3  GWTC-1-confident  1.126259e+09
# 1  GW151012-v3   GW151012        3  GWTC-1-confident  1.128679e+09
# 2  GW151226-v2   GW151226        2  GWTC-1-confident  1.135136e+09
# 3  GW170104-v2   GW170104        2  GWTC-1-confident  1.167560e+09
# 4  GW170608-v3   GW170608        3  GWTC-1-confident  1.180922e+09
#
#                            reference  \
# 0  https://doi.org/10.7935/82H3-HH23
# 1  https://doi.org/10.7935/82H3-HH23
# 2  https://doi.org/10.7935/82H3-HH23
# 3  https://doi.org/10.7935/82H3-HH23
# 4  https://doi.org/10.7935/82H3-HH23
#
#                                              jsonurl  mass_1_source  \
# 0  https://www.gw-openscience.org/eventapi/json/G...           35.6
# 1  https://www.gw-openscience.org/eventapi/json/G...           23.2
# 2  https://www.gw-openscience.org/eventapi/json/G...           13.7
# 3  https://www.gw-openscience.org/eventapi/json/G...           30.8
# 4  https://www.gw-openscience.org/eventapi/json/G...           11.0
#
#    mass_1_source_lower  mass_1_source_upper  ...  chirp_mass_upper  redshift  \
# 0                 -3.1                  4.7  ...               NaN      0.09
# 1                 -5.5                 14.9  ...               NaN      0.21
# 2                 -3.2                  8.8  ...               NaN      0.09
# 3                 -5.6                  7.3  ...               NaN      0.20
# 4                 -1.7                  5.5  ...               NaN      0.07
#
#    redshift_lower  redshift_upper           far  far_lower  far_upper  \
# 0           -0.03            0.03  1.000000e-07        NaN        NaN
# 1           -0.09            0.09  7.920000e-03        NaN        NaN
# 2           -0.04            0.04  1.000000e-07        NaN        NaN
# 3           -0.08            0.08  1.000000e-07        NaN        NaN
# 4           -0.02            0.02  1.000000e-07        NaN        NaN
#
#    final_mass_source  final_mass_source_lower  final_mass_source_upper
# 0               63.1                     -3.0                      3.4
# 1               35.6                     -3.8                     10.8
# 2               20.5                     -1.5                      6.4
# 3               48.9                     -4.0                      5.1
# 4               17.8                     -0.7                      3.4
#
# [5 rows x 40 columns]

# %%
gwtc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 40 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                50 non-null     object
#  1   commonName                        50 non-null     object
#  2   version                           50 non-null     int64
#  3   catalog.shortName                 50 non-null     object
#  4   GPS                               50 non-null     float64
#  5   reference                         50 non-null     object
#  6   jsonurl                           50 non-null     object
#  7   mass_1_source                     50 non-null     float64
#  8   mass_1_source_lower               50 non-null     float64
#  9   mass_1_source_upper               50 non-null     float64
#  10  mass_2_source                     50 non-null     float64
#  11  mass_2_source_lower               50 non-null     float64
#  12  mass_2_source_upper               50 non-null     float64
#  13  network_matched_filter_snr        50 non-null     float64
#  14  network_matched_filter_snr_lower  0 non-null      float64
#  15  network_matched_filter_snr_upper  0 non-null      float64
#  16  luminosity_distance               50 non-null     float64
#  17  luminosity_distance_lower         50 non-null     float64
#  18  luminosity_distance_upper         50 non-null     float64
#  19  chi_eff                           50 non-null     float64
#  20  chi_eff_lower                     50 non-null     float64
#  21  chi_eff_upper                     50 non-null     float64
#  22  total_mass_source                 39 non-null     float64
#  23  total_mass_source_lower           39 non-null     float64
#  24  total_mass_source_upper           39 non-null     float64
#  25  chirp_mass_source                 50 non-null     float64
#  26  chirp_mass_source_lower           50 non-null     float64
#  27  chirp_mass_source_upper           50 non-null     float64
#  28  chirp_mass                        39 non-null     float64
#  29  chirp_mass_lower                  39 non-null     float64
#  30  chirp_mass_upper                  39 non-null     float64
#  31  redshift                          50 non-null     float64
#  32  redshift_lower                    50 non-null     float64
#  33  redshift_upper                    50 non-null     float64
#  34  far                               50 non-null     float64
#  35  far_lower                         0 non-null      float64
#  36  far_upper                         0 non-null      float64
#  37  final_mass_source                 48 non-null     float64
#  38  final_mass_source_lower           47 non-null     float64
#  39  final_mass_source_upper           47 non-null     float64
# dtypes: float64(34), int64(1), object(5)
# memory usage: 15.8+ KB

# %%
gwtc.describe()
# Out:
#          version           GPS  mass_1_source  mass_1_source_lower  \
# count  50.000000  5.000000e+01      50.000000            50.000000
# mean    1.360000  1.228665e+09      34.967200            -7.002000
# std     0.721676  3.432955e+07      19.403191             5.543796
# min     1.000000  1.126259e+09       1.460000           -33.200000
# 25%     1.000000  1.239104e+09      23.225000            -8.800000
# 50%     1.000000  1.242379e+09      35.500000            -6.150000
# 75%     1.000000  1.248086e+09      42.025000            -3.125000
# max     3.000000  1.253886e+09      95.300000            -0.100000
#
#        mass_1_source_upper  mass_2_source  mass_2_source_lower  \
# count            50.000000      50.000000            50.000000
# mean             10.748400      22.797200            -6.419600
# std               8.589979      13.480208             4.624365
# min               0.120000       1.270000           -23.100000
# 25%               5.825000      10.800000            -8.700000
# 50%               9.350000      24.250000            -5.650000
# 75%              12.550000      30.300000            -2.625000
# max              52.700000      69.000000            -0.090000
#
#        mass_2_source_upper  network_matched_filter_snr  \
# count            50.000000                   50.000000
# mean              6.423400                   12.961324
# std               4.895419                    4.650431
# min               0.080000                    7.993908
# 25%               2.425000                   10.140310
# 50%               5.500000                   12.197685
# 75%               8.925000                   13.352789
# max              22.700000                   33.000000
#
#        network_matched_filter_snr_lower  ...  chirp_mass_upper   redshift  \
# count                               0.0  ...         39.000000  50.000000
# mean                                NaN  ...          5.957969   0.324400
# std                                 NaN  ...          6.836419   0.197072
# min                                 NaN  ...          0.000800   0.010000
# 25%                                 NaN  ...          0.450000   0.165000
# 50%                                 NaN  ...          5.300000   0.295000
# 75%                                 NaN  ...          7.700000   0.485000
# max                                 NaN  ...         32.200000   0.710000
#
#        redshift_lower  redshift_upper           far  far_lower  far_upper  \
# count       50.000000       50.000000  5.000000e+01        0.0        0.0
# mean        -0.132000        0.152980  1.186115e-01        NaN        NaN
# std          0.090306        0.120182  3.497065e-01        NaN        NaN
# min         -0.330000        0.000000  1.000000e-07        NaN        NaN
# 25%         -0.200000        0.060000  1.000000e-05        NaN        NaN
# 50%         -0.100000        0.110000  1.000000e-05        NaN        NaN
# 75%         -0.070000        0.247500  1.771534e-02        NaN        NaN
# max         -0.000000        0.490000  1.559222e+00        NaN        NaN
#
#        final_mass_source  final_mass_source_lower  final_mass_source_upper
# count          48.000000                47.000000                47.000000
# mean           57.225000                -7.219149                11.095745
# std            29.244949                 5.473479                 9.832001
# min             2.800000               -25.300000                 1.100000
# 25%            35.325000               -10.150000                 4.800000
# 50%            56.800000                -6.000000                 8.800000
# 75%            70.025000                -3.250000                13.550000
# max           156.300000                -0.700000                54.900000
#
# [8 rows x 35 columns]

# %%
gwtc_i = gwtc.set_index('id').sort_index()

# %%
gwtc_i.head()
# Out:
#             commonName  version catalog.shortName           GPS  \
# id
# GW150914-v3   GW150914        3  GWTC-1-confident  1.126259e+09
# GW151012-v3   GW151012        3  GWTC-1-confident  1.128679e+09
# GW151226-v2   GW151226        2  GWTC-1-confident  1.135136e+09
# GW170104-v2   GW170104        2  GWTC-1-confident  1.167560e+09
# GW170608-v3   GW170608        3  GWTC-1-confident  1.180922e+09
#
#                                      reference  \
# id
# GW150914-v3  https://doi.org/10.7935/82H3-HH23
# GW151012-v3  https://doi.org/10.7935/82H3-HH23
# GW151226-v2  https://doi.org/10.7935/82H3-HH23
# GW170104-v2  https://doi.org/10.7935/82H3-HH23
# GW170608-v3  https://doi.org/10.7935/82H3-HH23
#
#                                                        jsonurl  mass_1_source  \
# id
# GW150914-v3  https://www.gw-openscience.org/eventapi/json/G...           35.6
# GW151012-v3  https://www.gw-openscience.org/eventapi/json/G...           23.2
# GW151226-v2  https://www.gw-openscience.org/eventapi/json/G...           13.7
# GW170104-v2  https://www.gw-openscience.org/eventapi/json/G...           30.8
# GW170608-v3  https://www.gw-openscience.org/eventapi/json/G...           11.0
#
#              mass_1_source_lower  mass_1_source_upper  mass_2_source  ...  \
# id                                                                    ...
# GW150914-v3                 -3.1                  4.7           30.6  ...
# GW151012-v3                 -5.5                 14.9           13.6  ...
# GW151226-v2                 -3.2                  8.8            7.7  ...
# GW170104-v2                 -5.6                  7.3           20.0  ...
# GW170608-v3                 -1.7                  5.5            7.6  ...
#
#              chirp_mass_upper  redshift  redshift_lower  redshift_upper  \
# id
# GW150914-v3               NaN      0.09           -0.03            0.03
# GW151012-v3               NaN      0.21           -0.09            0.09
# GW151226-v2               NaN      0.09           -0.04            0.04
# GW170104-v2               NaN      0.20           -0.08            0.08
# GW170608-v3               NaN      0.07           -0.02            0.02
#
#                       far  far_lower  far_upper  final_mass_source  \
# id
# GW150914-v3  1.000000e-07        NaN        NaN               63.1
# GW151012-v3  7.920000e-03        NaN        NaN               35.6
# GW151226-v2  1.000000e-07        NaN        NaN               20.5
# GW170104-v2  1.000000e-07        NaN        NaN               48.9
# GW170608-v3  1.000000e-07        NaN        NaN               17.8
#
#              final_mass_source_lower  final_mass_source_upper
# id
# GW150914-v3                     -3.0                      3.4
# GW151012-v3                     -3.8                     10.8
# GW151226-v2                     -1.5                      6.4
# GW170104-v2                     -4.0                      5.1
# GW170608-v3                     -0.7                      3.4
#
# [5 rows x 39 columns]

# %%
gwtc_i.loc['GW150914-v3']
# Out:
# commonName                                                                   GW150914
# version                                                                             3
# catalog.shortName                                                    GWTC-1-confident
# GPS                                                                      1126259462.4
# reference                                           https://doi.org/10.7935/82H3-HH23
# jsonurl                             https://www.gw-openscience.org/eventapi/json/G...
# mass_1_source                                                                    35.6
# mass_1_source_lower                                                              -3.1
# mass_1_source_upper                                                               4.7
# mass_2_source                                                                    30.6
# mass_2_source_lower                                                              -4.4
# mass_2_source_upper                                                               3.0
# network_matched_filter_snr                                                       24.4
# network_matched_filter_snr_lower                                                  NaN
# network_matched_filter_snr_upper                                                  NaN
# luminosity_distance                                                             440.0
# luminosity_distance_lower                                                      -170.0
# luminosity_distance_upper                                                       150.0
# chi_eff                                                                         -0.01
# chi_eff_lower                                                                   -0.13
# chi_eff_upper                                                                    0.12
# total_mass_source                                                                 NaN
# total_mass_source_lower                                                           NaN
# total_mass_source_upper                                                           NaN
# chirp_mass_source                                                                28.6
# chirp_mass_source_lower                                                          -1.5
# chirp_mass_source_upper                                                           1.7
# chirp_mass                                                                        NaN
# chirp_mass_lower                                                                  NaN
# chirp_mass_upper                                                                  NaN
# redshift                                                                         0.09
# redshift_lower                                                                  -0.03
# redshift_upper                                                                   0.03
# far                                                                               0.0
# far_lower                                                                         NaN
# far_upper                                                                         NaN
# final_mass_source                                                                63.1
# final_mass_source_lower                                                          -3.0
# final_mass_source_upper                                                           3.4
# Name: GW150914-v3, dtype: object

# %%
gwtc_i.loc['GW150914-v3':'GW151226-v2']
# Out:
#             commonName  version catalog.shortName           GPS  \
# id
# GW150914-v3   GW150914        3  GWTC-1-confident  1.126259e+09
# GW151012-v3   GW151012        3  GWTC-1-confident  1.128679e+09
# GW151226-v2   GW151226        2  GWTC-1-confident  1.135136e+09
#
#                                      reference  \
# id
# GW150914-v3  https://doi.org/10.7935/82H3-HH23
# GW151012-v3  https://doi.org/10.7935/82H3-HH23
# GW151226-v2  https://doi.org/10.7935/82H3-HH23
#
#                                                        jsonurl  mass_1_source  \
# id
# GW150914-v3  https://www.gw-openscience.org/eventapi/json/G...           35.6
# GW151012-v3  https://www.gw-openscience.org/eventapi/json/G...           23.2
# GW151226-v2  https://www.gw-openscience.org/eventapi/json/G...           13.7
#
#              mass_1_source_lower  mass_1_source_upper  mass_2_source  ...  \
# id                                                                    ...
# GW150914-v3                 -3.1                  4.7           30.6  ...
# GW151012-v3                 -5.5                 14.9           13.6  ...
# GW151226-v2                 -3.2                  8.8            7.7  ...
#
#              chirp_mass_upper  redshift  redshift_lower  redshift_upper  \
# id
# GW150914-v3               NaN      0.09           -0.03            0.03
# GW151012-v3               NaN      0.21           -0.09            0.09
# GW151226-v2               NaN      0.09           -0.04            0.04
#
#                       far  far_lower  far_upper  final_mass_source  \
# id
# GW150914-v3  1.000000e-07        NaN        NaN               63.1
# GW151012-v3  7.920000e-03        NaN        NaN               35.6
# GW151226-v2  1.000000e-07        NaN        NaN               20.5
#
#              final_mass_source_lower  final_mass_source_upper
# id
# GW150914-v3                     -3.0                      3.4
# GW151012-v3                     -3.8                     10.8
# GW151226-v2                     -1.5                      6.4
#
# [3 rows x 39 columns]

# %%
gwtc_i.luminosity_distance
# Out:
# id
# GW150914-v3            440.0
# GW151012-v3           1080.0
# GW151226-v2            450.0
# GW170104-v2            990.0
# GW170608-v3            320.0
# GW170729-v1           2840.0
# GW170809-v1           1030.0
# GW170814-v3            600.0
# GW170817-v3             40.0
# GW170818-v1           1060.0
# GW170823-v1           1940.0
# GW190408_181802-v1    1550.0
# GW190412-v3            740.0
# GW190413_052954-v1    3550.0
# GW190413_134308-v1    4450.0
# GW190421_213856-v1    2880.0
# GW190424_180648-v1    2200.0
# GW190425-v2            160.0
# GW190426_152155-v1     370.0
# GW190503_185404-v1    1450.0
# GW190512_180714-v1    1430.0
# GW190513_205428-v1    2060.0
# GW190514_065416-v1    4130.0
# GW190517_055101-v1    1860.0
# GW190519_153544-v1    2530.0
# GW190521-v3           3920.0
# GW190521_074359-v1    1240.0
# GW190527_092055-v1    2490.0
# GW190602_175927-v1    2690.0
# GW190620_030421-v1    2810.0
# GW190630_185205-v1     890.0
# GW190701_203306-v1    2060.0
# GW190706_222641-v1    4420.0
# GW190707_093326-v1     770.0
# GW190708_232457-v1     880.0
# GW190719_215514-v1    3940.0
# GW190720_000836-v1     790.0
# GW190727_060333-v1    3300.0
# GW190728_064510-v1     870.0
# GW190731_140936-v1    3300.0
# GW190803_022701-v1    3270.0
# GW190814-v2            240.0
# GW190828_063405-v1    2130.0
# GW190828_065509-v1    1600.0
# GW190909_114149-v1    3770.0
# GW190910_112807-v1    1460.0
# GW190915_235702-v1    1620.0
# GW190924_021846-v1     570.0
# GW190929_012149-v1    2130.0
# GW190930_133541-v1     760.0
# Name: luminosity_distance, dtype: float64

# %%
(gwtc_i.luminosity_distance.max() * astropy.units.Mpc).to('lightyear')
# Out:
# <Quantity 1.45139588e+10 lyr>

# %%
gwtc_i['total_mass_source']
# Out:
# id
# GW150914-v3             NaN
# GW151012-v3             NaN
# GW151226-v2             NaN
# GW170104-v2             NaN
# GW170608-v3             NaN
# GW170729-v1             NaN
# GW170809-v1             NaN
# GW170814-v3             NaN
# GW170817-v3             NaN
# GW170818-v1             NaN
# GW170823-v1             NaN
# GW190408_181802-v1     43.0
# GW190412-v3            38.4
# GW190413_052954-v1     58.6
# GW190413_134308-v1     78.8
# GW190421_213856-v1     72.9
# GW190424_180648-v1     72.6
# GW190425-v2             3.4
# GW190426_152155-v1      7.2
# GW190503_185404-v1     71.7
# GW190512_180714-v1     35.9
# GW190513_205428-v1     53.9
# GW190514_065416-v1     67.2
# GW190517_055101-v1     63.5
# GW190519_153544-v1    106.6
# GW190521-v3           163.9
# GW190521_074359-v1     74.7
# GW190527_092055-v1     59.1
# GW190602_175927-v1    116.3
# GW190620_030421-v1     92.1
# GW190630_185205-v1     59.1
# GW190701_203306-v1     94.3
# GW190706_222641-v1    104.1
# GW190707_093326-v1     20.1
# GW190708_232457-v1     30.9
# GW190719_215514-v1     57.8
# GW190720_000836-v1     21.5
# GW190727_060333-v1     67.1
# GW190728_064510-v1     20.6
# GW190731_140936-v1     70.1
# GW190803_022701-v1     64.5
# GW190814-v2            25.8
# GW190828_063405-v1     58.0
# GW190828_065509-v1     34.4
# GW190909_114149-v1     75.0
# GW190910_112807-v1     79.6
# GW190915_235702-v1     59.9
# GW190924_021846-v1     13.9
# GW190929_012149-v1    104.3
# GW190930_133541-v1     20.3
# Name: total_mass_source, dtype: float64

# %%
# gwtc_i['total_mass_source'] = gwtc_i['mass_1_source'] + gwtc_i['mass_2_source']

# %%
missing = np.isnan(gwtc_i.total_mass_source)

# %%
missing
# Out:
# id
# GW150914-v3            True
# GW151012-v3            True
# GW151226-v2            True
# GW170104-v2            True
# GW170608-v3            True
# GW170729-v1            True
# GW170809-v1            True
# GW170814-v3            True
# GW170817-v3            True
# GW170818-v1            True
# GW170823-v1            True
# GW190408_181802-v1    False
# GW190412-v3           False
# GW190413_052954-v1    False
# GW190413_134308-v1    False
# GW190421_213856-v1    False
# GW190424_180648-v1    False
# GW190425-v2           False
# GW190426_152155-v1    False
# GW190503_185404-v1    False
# GW190512_180714-v1    False
# GW190513_205428-v1    False
# GW190514_065416-v1    False
# GW190517_055101-v1    False
# GW190519_153544-v1    False
# GW190521-v3           False
# GW190521_074359-v1    False
# GW190527_092055-v1    False
# GW190602_175927-v1    False
# GW190620_030421-v1    False
# GW190630_185205-v1    False
# GW190701_203306-v1    False
# GW190706_222641-v1    False
# GW190707_093326-v1    False
# GW190708_232457-v1    False
# GW190719_215514-v1    False
# GW190720_000836-v1    False
# GW190727_060333-v1    False
# GW190728_064510-v1    False
# GW190731_140936-v1    False
# GW190803_022701-v1    False
# GW190814-v2           False
# GW190828_063405-v1    False
# GW190828_065509-v1    False
# GW190909_114149-v1    False
# GW190910_112807-v1    False
# GW190915_235702-v1    False
# GW190924_021846-v1    False
# GW190929_012149-v1    False
# GW190930_133541-v1    False
# Name: total_mass_source, dtype: bool

# %%
gwtc_i.loc[missing, 'total_mass_source'] = (gwtc_i.loc[missing, 'mass_1_source'] +
                                            gwtc_i.loc[missing, 'mass_2_source'])

# %%
gwtc_i['total_mass_source']
# Out:
# id
# GW150914-v3            66.20
# GW151012-v3            36.80
# GW151226-v2            21.40
# GW170104-v2            50.80
# GW170608-v3            18.60
# GW170729-v1            84.20
# GW170809-v1            58.80
# GW170814-v3            55.80
# GW170817-v3             2.73
# GW170818-v1            62.10
# GW170823-v1            68.50
# GW190408_181802-v1     43.00
# GW190412-v3            38.40
# GW190413_052954-v1     58.60
# GW190413_134308-v1     78.80
# GW190421_213856-v1     72.90
# GW190424_180648-v1     72.60
# GW190425-v2             3.40
# GW190426_152155-v1      7.20
# GW190503_185404-v1     71.70
# GW190512_180714-v1     35.90
# GW190513_205428-v1     53.90
# GW190514_065416-v1     67.20
# GW190517_055101-v1     63.50
# GW190519_153544-v1    106.60
# GW190521-v3           163.90
# GW190521_074359-v1     74.70
# GW190527_092055-v1     59.10
# GW190602_175927-v1    116.30
# GW190620_030421-v1     92.10
# GW190630_185205-v1     59.10
# GW190701_203306-v1     94.30
# GW190706_222641-v1    104.10
# GW190707_093326-v1     20.10
# GW190708_232457-v1     30.90
# GW190719_215514-v1     57.80
# GW190720_000836-v1     21.50
# GW190727_060333-v1     67.10
# GW190728_064510-v1     20.60
# GW190731_140936-v1     70.10
# GW190803_022701-v1     64.50
# GW190814-v2            25.80
# GW190828_063405-v1     58.00
# GW190828_065509-v1     34.40
# GW190909_114149-v1     75.00
# GW190910_112807-v1     79.60
# GW190915_235702-v1     59.90
# GW190924_021846-v1     13.90
# GW190929_012149-v1    104.30
# GW190930_133541-v1     20.30
# Name: total_mass_source, dtype: float64

# %%
pp.plot(gwtc_i.total_mass_source, gwtc_i.luminosity_distance, '.')
pp.xlabel('total mass (Msun)')
pp.ylabel('luminosity distance (Mpc)')
# Out:
# Text(0, 0.5, 'luminosity distance (Mpc)')

# %%
gwtc_i.plot.scatter('total_mass_source', 'luminosity_distance', s=50,
                    figsize=(9,6))
# Out:
# <AxesSubplot:xlabel='total_mass_source', ylabel='luminosity_distance'>

# %%
gwtc_i.plot.scatter('total_mass_source', 'luminosity_distance',
                    s=gwtc['network_matched_filter_snr'] * 15,  # some trial-and-error to set sizes just right
                    linewidth=1, edgecolors='w',                # a white contour helps tell spots apart
                    c=gwtc['redshift'], colormap='plasma',     # set colors using colormap 
                    sharex=False,    # make sure x label does not disappear (thanks, stackoverflow.com)
                    figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='total_mass_source', ylabel='luminosity_distance'>

# %%
gwtc_i.plot.scatter('mass_1_source', 'mass_2_source',
                    s=gwtc['total_mass_source']*3,
                    linewidth=1, edgecolors='w',
                    c=gwtc['redshift'], colormap='plasma',
                    sharex=False, figsize=(10,6))

pp.plot([0,100],[0,100],'k:')
pp.plot([0,100],[0,50],'k:')
pp.plot([0,100],[0,20],'k:')

pp.axis([0,100,0,100]);
